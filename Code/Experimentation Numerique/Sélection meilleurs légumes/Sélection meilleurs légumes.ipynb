# %%
#paquet pour la modelisation et la resolution du programme linéaire
#from mip import *
#paquet pour utiliser des structures de données plus efficaces
from matplotlib.pyplot import *
import itertools as it
import numpy as np
import random as rand
from mip import *

# %% [markdown]
# # Programme principal

# %%
class Data() :
    
    def __init__(self,data_legume,data_terrain):
        #fill legum data first
        with open(data_legume,'r') as file:
            line = file.readline()  # lit la 1ère ligne
            lineTab = line.split()
            #print(lineTab)
            self.horizon = int(lineTab[0])
            self.an = 24
            self.nblegumes = int(lineTab[1])
            self.lnumber = np.empty(self.nblegumes+2)
            self.name = []
            self.family = np.empty(self.nblegumes+2)
            self.croissance = np.empty(self.nblegumes+2,dtype = int)
            self.rest = np.empty(self.nblegumes+2,dtype = int)
            self.price = []
            for i in range(self.nblegumes):
                line = file.readline()
                lineTab = line.split()
                self.lnumber[i]=int(lineTab[0])
                #print(lineTab[1])
                self.name.append(lineTab[1])
                #print(self.name[i])
                self.family[i]=int(lineTab[2])
                self.croissance[i]=int(lineTab[3])
                self.rest[i]=int(lineTab[4])
                priceofi = []
                for j in range (self.horizon):
                    priceofi.append(float(lineTab[j+5]))
                self.price.append(priceofi)
            #ajout fertilisation 
            line = file.readline()
            lineTab=line.split()
            self.lnumber[self.nblegumes]=int(lineTab[0])
            self.name.append(lineTab[1])
            self.family[self.nblegumes]=int(lineTab[2])
            self.croissance[self.nblegumes]=int(lineTab[3])
            self.rest[self.nblegumes]=0
            self.price.append(np.zeros(self.horizon))
            #ajout jachere
            line = file.readline()
            lineTab=line.split()
            self.lnumber[self.nblegumes+1]=int(lineTab[0])
            self.name.append(lineTab[1])
            self.family[self.nblegumes+1]=int(lineTab[2])
            self.croissance[self.nblegumes+1]=int(lineTab[3])
            self.rest[self.nblegumes+1]=0
            self.price.append(np.zeros(self.horizon))
            
        #fill parcell data
        with open(data_terrain,'r') as file:
            line = file.readline()
            lineTab = line.split()
            self.nbparcelle = int(lineTab[0])
            self.pnumber=np.empty(self.nbparcelle)
            self.surface=np.empty(self.nbparcelle)
            self.nbvoisin=np.empty(self.nbparcelle,dtype = int)
            self.voisin=[]
            for i in range(self.nbparcelle):
                line = file.readline()
                lineTab = line.split()
                self.pnumber[i]=int(lineTab[0])
                self.surface[i]=float(lineTab[1])
                self.nbvoisin[i]=int(lineTab[2])
                voisin_i=[]
                for j in range(self.nbvoisin[i]):
                    voisin_i.append(int(lineTab[3+j]))
                self.voisin.append(voisin_i)
                
    def resume(self):
        print("Resume du jeu de donnée :")
        print("Notre horizon de temps est constitué de ",self.horizon," périodes.")
        print("Le terrain est composée de ",self.nbparcelle," :")
        for i in range (self.nbparcelle):
            print("  -La parcelle ",self.pnumber[i]," a une surface de ",self.surface[i],"m2 et a ",self.nbvoisin[i]," voisins : ",self.voisin[i])
        print("Nous avons ",self.nblegumes," disponibles :")
        for i in range(self.nblegumes+2):
            print("  -Le légume ",self.lnumber[i]," ",self.name[i]," est de la famille ",self.family[i], " son temps de croissance est de ",self.croissance[i]," périodes.")
            print("la terre doit se reposer ",self.rest[i]," suite a sa culture")
    def legumeInfo(self,x):
        print( self.name[x]," suit le calendrier suivant :")
        print(self.price[x])


#start model test
def build_model(Data):
    model = Model(name = "solver", solver_name=CBC)
    #creating variables
    z=[[[model.add_var(name='z'+str(p)+'_'+str(l)+'_'+str(t),var_type=BINARY) for t in range (Data.horizon) ]for l in range (Data.nblegumes+2)]for p in range (Data.nbparcelle)]
    x=[[[model.add_var(name='x'+str(p)+'_'+str(l)+'_'+str(t),var_type=BINARY) for t in range (Data.horizon) ]for l in range (Data.nblegumes+2)]for p in range (Data.nbparcelle)]
    z = np.array(z)
    x = np.array(x)
    #objective
    model.objective = maximize(xsum(z[p][l][t]*Data.surface[p]*Data.price[l][t] for p in range(Data.nbparcelle) for l in range(Data.nblegumes+2) for t in range(Data.horizon) if abs(Data.price[l][t])>1e-6 ) ) #
    #constraint
    #fertilisation
    for p in range(Data.nbparcelle):
        model.add_constr(xsum(z[p][Data.nblegumes][t] for t in range (Data.horizon)) >=1)
    #jachere
    for p in range(Data.nbparcelle):
        model.add_constr(xsum(z[p][Data.nblegumes+1][t] for t in range (Data.horizon)) >=1)
    #une parcelle ne peut pas etre occupé par plus d'un legume
    for p in range(Data.nbparcelle):
        for t in range(Data.horizon):
            model.add_constr(xsum(x[p][l][t] for l in range(Data.nblegumes+2)) <= 1)
    #adjacence
    for p in range(Data.nbparcelle):
        for pprim in Data.voisin[p]:
            for l in range(Data.nblegumes+2):
                for t in range(Data.horizon):
                    model.add_constr(xsum(x[pprim][lprim][t] for lprim in range(Data.nblegumes+2) if Data.family[lprim]==Data.family[l] and Data.lnumber[lprim] != Data.lnumber[l])  <= 1-x[p][l][t] )
    #continuite
    for p in range(Data.nbparcelle):
        for l in range(Data.nblegumes+2):
            for t in range(Data.horizon):
                model.add_constr(xsum(z[p][lprim][tprim] for lprim in range(Data.nblegumes+2) for tprim in range( (t-Data.croissance[lprim]-Data.rest[lprim]+1)%Data.horizon ,t) if Data.family[lprim]==Data.family[l] ) <= 1-z[p][l][t] )
                model.add_constr(xsum(z[p][l][tprim] for tprim in range(t-Data.croissance[l]+1,t+1))  == x[p][l][t] )                         
    return model



def model_solution(Data):
    model  = build_model(Data)
    status = model.optimize(max_seconds=300)
    if status == OptimizationStatus.OPTIMAL:
        print('optimal solution cost {} found'.format(model.objective_value))
    elif status == OptimizationStatus.FEASIBLE:
        print('sol.cost {} found, best possible: {}'.format(model.objective_value, model.objective_bound))
    elif status == OptimizationStatus.NO_SOLUTION_FOUND:
        print('no feasible solution found, lower bound is: {}'.format(model.objective_bound))
    if status == OptimizationStatus.OPTIMAL or status == OptimizationStatus.FEASIBLE:
        solution=[]
        for p in range(Data.nbparcelle):
            for l in range(Data.nblegumes+2):
                for t in range(Data.horizon):
                    if model.vars[(Data.nblegumes+2)*Data.horizon*p+Data.horizon*l+t].x > 1e-6:
                            solution.append([p,l,t])
    return solution

class solution():
    
    def __init__(self,solution,Data):
        self.data = Data
        self.solution = solution
        
    def profits(self):
        profits = 0
        for i in self.solution:
            profits+= self.data.surface[i[0]]*self.data.price[i[1]][i[2]]
        return profits
                    
    def disp(self,details=False):
        print("Nous pouvons générer un profit de {}euro en suivant le calendrier suivant".format(self.profits()))
        print("Calendrier :")
        for i in self.solution:
            print("  Sur la parcelle {}, on plante {} à la période {}".format(i[0],self.data.name[i[1]],i[2]))
            if details==True:
                print("    -Il va l'occuper pendant {} périodes et la terre devra se reposer {} périodes".format(self.data.croissance[i[1]],self.data.rest[[i[1]]]))
            
    
    def verif (self):
        Data=self.data
        t = self.solution 
        cpt_f=np.zeros(Data.nbparcelle)
        cpt_j=np.zeros(Data.nbparcelle)
        verified = True
        for i in t:
            for j in t:
                if j!=i:
                    #continuite plus occupation
                    if i[0]==j[0]:
                        if Data.family[i[1]]==Data.family[j[1]]:
                            if i[2]<=j[2]<=i[2]+Data.croissance[i[1]]+Data.rest[i[1]]-1:
                                print("continuité pas respectée même famille")
                                print(i)
                                print(j)
                                Verified = False
                        else :
                            if i[2]<=j[2]<=i[2]+Data.croissance[i[1]]-1:
                                print("continuité pas respectée")
                                print(i)
                                print(j)
                                Verified = False
                    #voisinage
                    elif j[0] in Data.voisin[i[0]]:
                        if Data.family[j[1]]==Data.family[i[1]] and j[1]!=i[1]:
                            if i[2]<=j[2]<=i[2]+Data.croissance[2]-1:
                                print("voisinage")
                                print(i)
                                print(j)


                #fertil et jachere       
                if i[1]==Data.nblegumes:
                    cpt_f[i[0]]+=1
                if i[1]==Data.nblegumes + 1:
                    cpt_j[i[0]]+=1
        for v in range(Data.nbparcelle):
            if (cpt_f[v]<1 or cpt_j[v]<1):
                print("Jachere ferti pas faite")
                verified = False
        
        #conclusion
        if verified == True:
            print("la solution est valide")
        else:
            print("la solution n'est pas valide")
            
# Fonction permettant de connaître le légume ayant la croissance la plus courte

def croiss_min(data):
    mini = data.croissance[0]
    ind = 0
    for i in range ( 1 , data.nblegumes):
        if ( data.croissance[i]< mini ):
            mini = data.croissance[i]
            ind = i 
    return mini


# Fonction permettant de vérifier qu'on a le temps de planter sur une parcelle p dont l'occupation 
# est représentée par le tableau t un légume l à une période tps

def verif_plant( t , p ,  leg, tps , data) :
    k = data.croissance[leg]
    bool = True
    T = t[p]
    # Vérif temps de croissance libre
    if ( tps+k > data.horizon):
        bool = False
    else : 
        for i in range ( 0 , data.nblegumes+2 ):
            for j in range (tps , tps + k):
                if (T[i][j]==1):
                    bool = False
    # Vérif continuité
    LstFam=[]
    for i in range (0, data.nblegumes):
         if (data.family[leg] == data.family[i]):
            LstFam+=[i]
    if (bool==True):
        for l in (LstFam) :
            if (T[l][tps-1]==1):
                bool = False
    # Vérif Adjacence
    # On fait la liste des légumes de la même famille que l
        if (bool==True):
            for i in data.voisin[leg]:
                for l in (LstFam):
                    if t[i][l][tps]==1:
                        bool = False
    return bool

    
# Fonction créant un calendrier aléatoire respectant les contraintes

def aleatoire(data):
    #Création du tableau vide de dimension : nbparcelles * nblegumes * nb périodes
    t = [[[0 for t in range (data.horizon)] for l in range (data.nblegumes + 2)] for p in range (data.nbparcelle)]
    tz = [[[0 for t in range (data.horizon)] for l in range (data.nblegumes + 2)] for p in range (data.nbparcelle)]
    #On tire au hasard pour chaque parcelle le début de la fertilisation puis le début de la jachère
    for i in range (data.nbparcelle):
        P=[i for i in range (0, data.horizon + 1 - data.croissance[data.nblegumes+1])]
        k=rand.randint(0, (data.horizon - data.croissance[data.nblegumes]))
        for j in range ( k - data.croissance[data.nblegumes+1] + 1 , k ):
            if j in P:
                P.remove(j)
        tz [i][data.nblegumes][k] = 1
        for j in range ( k , k + data.croissance[data.nblegumes] ):
            t[i][data.nblegumes][j]=1
            if j in P:
                P.remove(j)
        k = rand.choice(P)
        tz [i][data.nblegumes+1][k] = 1
        for j in range ( k , k + data.croissance[data.nblegumes+1] ):
            t[i][data.nblegumes+1][j]=1
    LstParc = [k for k in range (data.nbparcelle)] 
    count = 0
    for k in range ( 0 , data.nbparcelle):
        # On tire au hasard une parcelle à remplir
        p = rand.choice(LstParc)
        LstParc.remove(p)
        # On remplit la parcelle p
        tps = 0
        # On passe par toutes les périodes de temps
        while (tps <= data.horizon - croiss_min(data) ):
            LstLeg = [l for l in range (data.nblegumes)]
            V = False
            while ( V == False and len(LstLeg)!=0):
                l = rand.choice(LstLeg)
                LstLeg.remove(l)
                V = verif_plant( t , p , l , tps , data)
                if ( V == True ): 
                    tz[p][l][tps]=1
                    for i in range ( tps ,  tps + data.croissance[l] ):
                        t[p][l][i]=1
            tps += 1
    return (tz)  


# Fonction calculant la rentabilité d'un calendrier

def rentabilite ( tz , datal , datat ):
    data=Data(datal,datat)
    sum = 0
    for p in range (0, len(tz)):
        for l in range (0, data.nblegumes):
            if 1 in tz[p][l] :
                for t in range (0, data.horizon):
                    sum+=data.price[l][t]
    return sum


# Fonction retournant le meilleur calendrier parmi n créés

def best_aleatoire ( datal, datat, n):
    data=Data(datal,datat)
    t = aleatoire(data)
    t2 = []
    maxi = rentabilite(t,datal,datat)
    for i in range (1,n):
        t2 = aleatoire(data)
        if ( rentabilite(t2,datal,datat) > maxi ):
            t = t2
            maxi = rentabilite (t,datal,datat)
    return (t)

# best_aleatoire(datal,datat,10)

# Transformation calendrier de z en class solution

def solutionAl(vec,Data):
    solution=[]
    for p in range(Data.nbparcelle):
        for l in range(Data.nblegumes+2):
            for t in range(Data.horizon):
                if vec[p][l][t] > 1e-6:
                        solution.append([p,l,t])
    return solution


# Fonction vérifiant la validité d'un échantillon de n calendriers aléatoires

def verif_aleatoire( n , data ):
    bool=True
    k=0
    while (bool==True and k<n):
        if (( solutionAl(aleatoire(data),data).verif ) == False):
            bool==False
        k+=1
    return bool

# %% [markdown]
# #  Etablissement d'un graphique représentant la répartition des rentabilités des calendriers aléatoires, pour n calendriers

# %%
import matplotlib as plt

def repartition ( n , data ):
    sol=model_solution(data)
    S=solution(sol,data)
    maxi= int(S.profits())
    print(maxi)
    V=[0 for i in range (maxi+1)]
    for i in range (n):
        V[int( solution(solutionAl(aleatoire(data), data ),data).profits())] += 1
    
    matplotlib.pyplot.plot(V)

# %% [markdown]
# ### On trace la répartition des profits des calendriers aléatoires

# %%
#datat="DataSet/data_terrain_petit.txt"
#datal="DataSet/data_legumes_petit.txt"
#data=Data(datal,datat)

#repartition(5000,data)
# Out:
# Cgl0003I 0 fixed, 0 tightened bounds, 724 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 709 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 581 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 566 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 526 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 457 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 433 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 398 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 321 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1466 rows, 1044 columns (1044 integer (1044 of which binary)) and 11875 elements
# Coin3009W Conflict graph built in 0.003 seconds, density: 0.964%
# Cgl0015I Clique Strengthening extended 142 cliques, 401 were dominated
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -495000
# Cbc0038I Before mini branch and bound, 1044 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.93 seconds)
# Cbc0038I After 0.93 seconds - Feasibility pump exiting with objective of -495000 - took 0.00 seconds
# Cbc0012I Integer solution of -495000 found by feasibility pump after 0 iterations and 0 nodes (0.93 seconds)
# Cbc0001I Search completed - best objective -495000, took 0 iterations and 0 nodes (0.93 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.91   (Wallclock seconds):       0.97
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 330 (-948) rows, 270 (-450) columns and 1242 (-1581) elements
# Clp1000I sum of infeasibilities 1.78332e-07 - average 5.40401e-10, 144 fixed columns
# Coin0506I Presolve 150 (-180) rows, 126 (-144) columns and 444 (-798) elements
# Clp0006I 0  Obj 306750 Dual inf 6787.4999 (78)
# Clp0029I End of values pass after 126 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000004 - largest nonzero change 2.7814208e-05 ( 0.0013907104%) - largest zero change 2.9394864e-05
# Clp0000I Optimal - objective value 306750
# Clp0000I Optimal - objective value 306750
# Coin0511I After Postsolve, objective 306750, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 306750 Dual inf 208350 (54)
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.9669814e-05 ( 0.0014834907%) - largest zero change 2.9394864e-05
# Clp0000I Optimal - objective value 306750
# Clp0000I Optimal - objective value 306750
# Clp0000I Optimal - objective value 306750
# Coin0511I After Postsolve, objective 306750, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 306750 - 0 iterations time 0.042, Presolve 0.00, Idiot 0.04
#
# Starting MIP optimization
# optimal solution cost 284250.0 found
# 284250

# %% [markdown]
# # Définition des légumes les plus rentables dans une grande base de données

# %% [markdown]
# ### Création d'un fichier texte "data_legumes_new.txt" comportant des légumes sélectionnés dans "data_legumes_grand.txt"

# %%
def selection_legumes( datal, k, V ):
    file = open("data_legumes_new"+str(k)+".txt","w")
    source = open( datal, "r" )
    lignes = source.readlines()
    file.write(lignes[0].replace("10",str(len(V))))
    for i in range(len(V)):
        if (V[i]>len(lignes)-5):
            return "Error"
        else:
            file.write(str(i) + lignes[V[i]+1][1:])
    file.write(str(len(V))+lignes[len(lignes)-2][2:])
    file.write(str(len(V)+1)+lignes[len(lignes)-1][2:])

# %% [markdown]
# ### Création de toutes les listes de k éléments distincts d'une liste T

# %%
def combinaisons(k,T):
    V=list(it.combinations(T,k))
    return V

# %% [markdown]
# ### Programme définissant quelle est la meilleure combinaison de k légumes parmi un grand nombre pour un agriculteur

# %%
def best_selection_legumes (datal,datat,k):
    data=Data(datal,datat)
    L=[i for i in range (0,data.nblegumes-1)]
    V=combinaisons(k,L)
    selection_legumes(datal, 0, list(V[0]))
    datal_2="data_legumes_new0.txt"
    data2=Data(datal_2,datat)
    best=0
    sol = model_solution(data2)
    S=solution(sol,data)
    max = S.profits()
    for i in range (1,len(V)-1):
        selection_legumes(datal,i,list(V[i]))
        print (V[i])
        datal_2="data_legumes_new"+str(i)+".txt"
        data2=Data(datal_2,datat)
        sol = model_solution(data2)
        S = solution(sol,data2)
        if((S.profits())>max):
            max=S.profits()
            best=i
    return list(V[i])

# %% [markdown]
# ### On détermine quel est le meilleur triplet de légumes parmi les 10 composant le fichier "data_legumes_grand.txt"

# %%
# datat="DataSet/data_terrain_petit.txt"
# datal="DataSet/data_legumes_grand.txt"
# data=Data(datal,datat)

# best_selection_legumes(datal,datat,3)
# Out:
# Cgl0003I 0 fixed, 0 tightened bounds, 252 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 252 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 207 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 123 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 94 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 52 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 189 rows, 270 columns (270 integer (270 of which binary)) and 1248 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 1.140%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 33 integers unsatisfied sum - 16.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -224700 iterations 176
# Cbc0038I Solution found of -224700
# Cbc0038I Rounding solution of -267000 is better than previous of -224700
#
# Cbc0038I Before mini branch and bound, 235 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 189 rows 270 columns, reduced to 34 rows 30 columns
# Cbc0038I Mini branch and bound improved solution from -267000 to -276000 (0.09 seconds)
# Cbc0038I Round again with cutoff of -277155
# Cbc0038I Pass   2: suminf.    6.03667 (20) obj. -277155 iterations 85
# Cbc0038I Pass   3: suminf.    4.26111 (9) obj. -277155 iterations 38
# Cbc0038I Pass   4: suminf.    3.26111 (7) obj. -277155 iterations 18
# Cbc0038I Pass   5: suminf.    3.26111 (7) obj. -277155 iterations 12
# Cbc0038I Pass   6: suminf.    3.28500 (7) obj. -277155 iterations 73
# Cbc0038I Pass   7: suminf.    3.28500 (7) obj. -277155 iterations 53
# Cbc0038I Pass   8: suminf.    3.26111 (7) obj. -277155 iterations 15
# Cbc0038I Pass   9: suminf.    3.32000 (7) obj. -277155 iterations 90
# Cbc0038I Pass  10: suminf.    1.93175 (9) obj. -277155 iterations 104
# Cbc0038I Pass  11: suminf.    1.76111 (4) obj. -277155 iterations 87
# Cbc0038I Pass  12: suminf.    1.76111 (4) obj. -277155 iterations 8
# Cbc0038I Pass  13: suminf.    1.76111 (4) obj. -277155 iterations 4
# Cbc0038I Pass  14: suminf.    2.00000 (4) obj. -277800 iterations 69
# Cbc0038I Pass  15: suminf.    1.93175 (9) obj. -277155 iterations 27
# Cbc0038I Pass  16: suminf.    1.76111 (4) obj. -277155 iterations 76
# Cbc0038I Pass  17: suminf.    1.76111 (4) obj. -277155 iterations 7
# Cbc0038I Pass  18: suminf.    1.76111 (4) obj. -277155 iterations 4
# Cbc0038I Pass  19: suminf.    2.00000 (4) obj. -277800 iterations 64
# Cbc0038I Pass  20: suminf.    1.93175 (9) obj. -277155 iterations 25
# Cbc0038I Pass  21: suminf.    1.76111 (4) obj. -277155 iterations 78
# Cbc0038I Pass  22: suminf.    1.76111 (4) obj. -277155 iterations 7
# Cbc0038I Pass  23: suminf.    1.76111 (4) obj. -277155 iterations 13
# Cbc0038I Pass  24: suminf.    1.76111 (4) obj. -277155 iterations 15
# Cbc0038I Pass  25: suminf.    1.76111 (4) obj. -277155 iterations 2
# Cbc0038I Pass  26: suminf.    2.00000 (4) obj. -277800 iterations 71
# Cbc0038I Pass  27: suminf.    1.93175 (9) obj. -277155 iterations 29
# Cbc0038I Pass  28: suminf.    1.76111 (4) obj. -277155 iterations 88
# Cbc0038I Pass  29: suminf.    4.84667 (16) obj. -277155 iterations 92
# Cbc0038I Pass  30: suminf.    2.90000 (6) obj. -277155 iterations 39
# Cbc0038I Pass  31: suminf.    2.11290 (5) obj. -277155 iterations 9
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 197 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 189 rows 270 columns, reduced to 82 rows 71 columns
# Cbc0038I Mini branch and bound improved solution from -276000 to -280275 (0.13 seconds)
# Cbc0038I Round again with cutoff of -281655
# Cbc0038I Pass  31: suminf.   11.50000 (27) obj. -281655 iterations 20
# Cbc0038I Pass  32: suminf.    5.40000 (11) obj. -281655 iterations 43
# Cbc0038I Pass  33: suminf.    4.70000 (10) obj. -281655 iterations 47
# Cbc0038I Pass  34: suminf.    4.70000 (10) obj. -281655 iterations 23
# Cbc0038I Pass  35: suminf.    4.70000 (10) obj. -281655 iterations 27
# Cbc0038I Pass  36: suminf.    3.70000 (8) obj. -281655 iterations 20
# Cbc0038I Pass  37: suminf.    3.70000 (8) obj. -281655 iterations 3
# Cbc0038I Pass  38: suminf.    3.76000 (8) obj. -281655 iterations 46
# Cbc0038I Pass  39: suminf.    3.70000 (8) obj. -281655 iterations 24
# Cbc0038I Pass  40: suminf.    3.70000 (8) obj. -281655 iterations 21
# Cbc0038I Pass  41: suminf.    3.70000 (8) obj. -281655 iterations 17
# Cbc0038I Pass  42: suminf.    3.70000 (8) obj. -281655 iterations 4
# Cbc0038I Pass  43: suminf.    7.80000 (17) obj. -281655 iterations 92
# Cbc0038I Pass  44: suminf.    4.64255 (10) obj. -281655 iterations 73
# Cbc0038I Pass  45: suminf.    3.76000 (8) obj. -281655 iterations 74
# Cbc0038I Pass  46: suminf.    3.70000 (8) obj. -281655 iterations 28
# Cbc0038I Pass  47: suminf.    3.70000 (8) obj. -281655 iterations 23
# Cbc0038I Pass  48: suminf.    3.70000 (8) obj. -281655 iterations 14
# Cbc0038I Pass  49: suminf.    3.73333 (8) obj. -281655 iterations 53
# Cbc0038I Pass  50: suminf.    3.70000 (8) obj. -281655 iterations 25
# Cbc0038I Pass  51: suminf.    3.70000 (8) obj. -281655 iterations 6
# Cbc0038I Pass  52: suminf.    3.58621 (8) obj. -281655 iterations 20
# Cbc0038I Pass  53: suminf.    3.58621 (8) obj. -281655 iterations 14
# Cbc0038I Pass  54: suminf.    5.20909 (17) obj. -281655 iterations 75
# Cbc0038I Pass  55: suminf.    3.81538 (10) obj. -281655 iterations 101
# Cbc0038I Pass  56: suminf.    4.70000 (10) obj. -281655 iterations 102
# Cbc0038I Pass  57: suminf.    3.70000 (8) obj. -281655 iterations 24
# Cbc0038I Pass  58: suminf.    3.70000 (8) obj. -281655 iterations 22
# Cbc0038I Pass  59: suminf.    3.70000 (8) obj. -281655 iterations 24
# Cbc0038I Pass  60: suminf.    3.70000 (8) obj. -281655 iterations 16
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 209 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 189 rows 270 columns, reduced to 62 rows 59 columns
# Cbc0038I Mini branch and bound did not improve solution (0.19 seconds)
# Cbc0038I After 0.19 seconds - Feasibility pump exiting with objective of -280275 - took 0.11 seconds
# Cbc0012I Integer solution of -280275 found by feasibility pump after 0 iterations and 0 nodes (0.19 seconds)
# Cbc0012I Integer solution of -280650 found by DiveCoefficient after 0 iterations and 0 nodes (0.20 seconds)
# Cbc0038I Full problem 189 rows 270 columns, reduced to 42 rows 40 columns
# Cbc0012I Integer solution of -280875 found by RINS after 0 iterations and 0 nodes (0.21 seconds)
# Cbc0012I Integer solution of -284250 found by DiveCoefficient after 33 iterations and 0 nodes (0.22 seconds)
# Cbc0031I 5 added rows had average density of 30.8
# Cbc0013I At root node, 5 cuts changed objective from -286875 to -284250 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 32.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 5 row cuts average 30.8 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -284250, took 33 iterations and 0 nodes (0.22 seconds)
# Cbc0035I Maximum depth 0, 12 variables fixed on reduced cost
# Total time (CPU seconds):       0.24   (Wallclock seconds):       0.26
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 513 (-765) rows, 360 (-360) columns and 2106 (-1173) elements
# Clp1000I sum of infeasibilities 2.11663e-07 - average 4.12599e-10, 48 fixed columns
# Coin0506I Presolve 405 (-108) rows, 266 (-94) columns and 1771 (-335) elements
# Clp0006I 0  Obj 324468.62 Dual inf 14235 (158)
# Clp0029I End of values pass after 266 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.919357e-05 ( 0.0014596785%) - largest zero change 1.6474992e-05
# Clp0000I Optimal - objective value 324479.17
# Clp0000I Optimal - objective value 324479.17
# Coin0511I After Postsolve, objective 324479.17, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 324479.17 Dual inf 39000 (10)
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.7896127e-05 ( 0.0013948063%) - largest zero change 2.9019187e-05
# Clp0000I Optimal - objective value 324479.17
# Clp0000I Optimal - objective value 324479.17
# Clp0000I Optimal - objective value 324479.17
# Coin0511I After Postsolve, objective 324479.17, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 324479.1667 - 0 iterations time 0.102, Presolve 0.00, Idiot 0.10
#
# Starting MIP optimization
# optimal solution cost 270000.0 found
# (0, 1, 3)
# Cgl0003I 0 fixed, 0 tightened bounds, 291 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 290 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 227 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 214 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 119 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 77 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 50 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0004I processed model has 321 rows, 360 columns (360 integer (360 of which binary)) and 1870 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 1.134%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 117 integers unsatisfied sum - 51
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -9000 iterations 180
# Cbc0038I Solution found of -9000
# Cbc0038I Rounding solution of -198000 is better than previous of -9000
#
# Cbc0038I Before mini branch and bound, 239 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 321 rows 360 columns, reduced to 138 rows 90 columns
# Cbc0038I Mini branch and bound improved solution from -198000 to -261000 (0.26 seconds)
# Cbc0038I Round again with cutoff of -263825
# Cbc0038I Pass   2: suminf.   19.03611 (52) obj. -263825 iterations 183
# Cbc0038I Pass   3: suminf.    6.76667 (19) obj. -263825 iterations 82
# Cbc0038I Pass   4: suminf.    6.06389 (16) obj. -263825 iterations 14
# Cbc0038I Pass   5: suminf.    5.59259 (12) obj. -263825 iterations 82
# Cbc0038I Pass   6: suminf.    5.59259 (12) obj. -263825 iterations 59
# Cbc0038I Pass   7: suminf.    0.44722 (7) obj. -263825 iterations 124
# Cbc0038I Pass   8: suminf.    0.44722 (7) obj. -263825 iterations 72
# Cbc0038I Pass   9: suminf.    1.50000 (3) obj. -266250 iterations 108
# Cbc0038I Pass  10: suminf.    0.89375 (3) obj. -263825 iterations 14
# Cbc0038I Pass  11: suminf.    0.89375 (3) obj. -263825 iterations 67
# Cbc0038I Pass  12: suminf.    0.89375 (3) obj. -263825 iterations 85
# Cbc0038I Pass  13: suminf.    0.89375 (3) obj. -263825 iterations 58
# Cbc0038I Pass  14: suminf.    0.89375 (3) obj. -263825 iterations 74
# Cbc0038I Pass  15: suminf.    2.67500 (14) obj. -263825 iterations 114
# Cbc0038I Pass  16: suminf.    2.42708 (5) obj. -263825 iterations 108
# Cbc0038I Pass  17: suminf.    2.42708 (5) obj. -263825 iterations 94
# Cbc0038I Pass  18: suminf.    1.45625 (3) obj. -263825 iterations 106
# Cbc0038I Pass  19: suminf.    1.45625 (3) obj. -263825 iterations 88
# Cbc0038I Pass  20: suminf.    1.45625 (3) obj. -263825 iterations 93
# Cbc0038I Pass  21: suminf.    1.45625 (3) obj. -263825 iterations 68
# Cbc0038I Pass  22: suminf.    3.88056 (11) obj. -263825 iterations 103
# Cbc0038I Solution found of -267000
# Cbc0038I Before mini branch and bound, 197 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 321 rows 360 columns, reduced to 191 rows 133 columns - 2 fixed gives 189, 130 - still too large
# Cbc0038I Full problem 321 rows 360 columns, reduced to 189 rows 130 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.34 seconds)
# Cbc0038I Round again with cutoff of -270700
# Cbc0038I Pass  23: suminf.   19.18333 (79) obj. -270700 iterations 11
# Cbc0038I Pass  24: suminf.    6.55926 (14) obj. -270700 iterations 97
# Cbc0038I Pass  25: suminf.    6.55926 (14) obj. -270700 iterations 9
# Cbc0038I Pass  26: suminf.    5.93333 (18) obj. -270700 iterations 173
# Cbc0038I Pass  27: suminf.    5.93333 (18) obj. -270700 iterations 9
# Cbc0038I Pass  28: suminf.    5.72593 (17) obj. -270700 iterations 95
# Cbc0038I Pass  29: suminf.    5.62222 (21) obj. -270700 iterations 53
# Cbc0038I Pass  30: suminf.    5.93333 (19) obj. -270700 iterations 87
# Cbc0038I Pass  31: suminf.    5.51852 (20) obj. -270700 iterations 78
# Cbc0038I Pass  32: suminf.    2.29444 (7) obj. -270700 iterations 128
# Cbc0038I Pass  33: suminf.    0.98333 (3) obj. -270700 iterations 48
# Cbc0038I Pass  34: suminf.    1.50000 (3) obj. -272250 iterations 84
# Cbc0038I Pass  35: suminf.    0.98333 (3) obj. -270700 iterations 61
# Cbc0038I Pass  36: suminf.    0.98333 (3) obj. -270700 iterations 26
# Cbc0038I Pass  37: suminf.    0.98333 (3) obj. -270700 iterations 78
# Cbc0038I Pass  38: suminf.    0.98333 (3) obj. -270700 iterations 61
# Cbc0038I Pass  39: suminf.    0.98333 (3) obj. -270700 iterations 82
# Cbc0038I Pass  40: suminf.    3.91667 (22) obj. -270700 iterations 150
# Cbc0038I Pass  41: suminf.    2.95000 (6) obj. -270700 iterations 86
# Cbc0038I Pass  42: suminf.    0.98333 (3) obj. -270700 iterations 138
# Cbc0038I Pass  43: suminf.    0.98333 (3) obj. -270700 iterations 55
# Cbc0038I Pass  44: suminf.    1.50000 (3) obj. -272250 iterations 87
# Cbc0038I Pass  45: suminf.    0.98333 (3) obj. -270700 iterations 62
# Cbc0038I Pass  46: suminf.    0.98333 (3) obj. -270700 iterations 33
# Cbc0038I Pass  47: suminf.    0.98333 (3) obj. -270700 iterations 72
# Cbc0038I Pass  48: suminf.    0.98333 (3) obj. -270700 iterations 54
# Cbc0038I Pass  49: suminf.    0.98333 (3) obj. -270700 iterations 97
# Cbc0038I Pass  50: suminf.    2.18889 (6) obj. -270700 iterations 114
# Cbc0038I Pass  51: suminf.    0.98333 (3) obj. -270700 iterations 141
# Cbc0038I Pass  52: suminf.    0.98333 (3) obj. -270700 iterations 42
# Cbc0038I Rounding solution of -267750 is better than previous of -267000
#
# Cbc0038I Before mini branch and bound, 194 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 321 rows 360 columns, reduced to 195 rows 133 columns - 8 fixed gives 93, 73 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.42 seconds)
# Cbc0038I Round again with cutoff of -274240
# Cbc0038I Reduced cost fixing fixed 2 variables on major pass 4
# Cbc0038I Pass  52: suminf.   22.98667 (69) obj. -274240 iterations 31
# Cbc0038I Pass  53: suminf.   10.30741 (22) obj. -274240 iterations 70
# Cbc0038I Pass  54: suminf.    9.30741 (20) obj. -274240 iterations 26
# Cbc0038I Pass  55: suminf.    9.30741 (20) obj. -274240 iterations 3
# Cbc0038I Pass  56: suminf.    9.23037 (19) obj. -274240 iterations 50
# Cbc0038I Pass  57: suminf.    8.30741 (22) obj. -274240 iterations 34
# Cbc0038I Pass  58: suminf.    8.30741 (17) obj. -274240 iterations 84
# Cbc0038I Pass  59: suminf.    8.30741 (22) obj. -274240 iterations 61
# Cbc0038I Pass  60: suminf.    6.46148 (13) obj. -274240 iterations 86
# Cbc0038I Pass  61: suminf.    3.53852 (8) obj. -274240 iterations 25
# Cbc0038I Pass  62: suminf.    3.35556 (8) obj. -274240 iterations 76
# Cbc0038I Pass  63: suminf.    2.41333 (6) obj. -274240 iterations 49
# Cbc0038I Pass  64: suminf.    2.35556 (5) obj. -274240 iterations 54
# Cbc0038I Pass  65: suminf.    2.35556 (5) obj. -274240 iterations 24
# Cbc0038I Pass  66: suminf.    2.32667 (8) obj. -274240 iterations 152
# Cbc0038I Pass  67: suminf.    3.29778 (7) obj. -274240 iterations 68
# Cbc0038I Pass  68: suminf.    3.17278 (12) obj. -274240 iterations 15
# Cbc0038I Pass  69: suminf.    3.17278 (12) obj. -274240 iterations 18
# Cbc0038I Pass  70: suminf.    2.41852 (8) obj. -274240 iterations 116
# Cbc0038I Pass  71: suminf.    2.41852 (8) obj. -274240 iterations 77
# Cbc0038I Pass  72: suminf.    2.74750 (6) obj. -274240 iterations 135
# Cbc0038I Pass  73: suminf.    2.74750 (6) obj. -274240 iterations 67
# Cbc0038I Pass  74: suminf.    2.66333 (6) obj. -274240 iterations 100
# Cbc0038I Pass  75: suminf.    2.66333 (6) obj. -274240 iterations 71
# Cbc0038I Pass  76: suminf.    7.56111 (19) obj. -274240 iterations 104
# Cbc0038I Pass  77: suminf.    3.33667 (9) obj. -274240 iterations 104
# Cbc0038I Pass  78: suminf.    2.66333 (6) obj. -274240 iterations 77
# Cbc0038I Pass  79: suminf.    2.66333 (6) obj. -274240 iterations 40
# Cbc0038I Pass  80: suminf.    2.66333 (6) obj. -274240 iterations 117
# Cbc0038I Pass  81: suminf.    2.66333 (6) obj. -274240 iterations 77
# Cbc0038I Rounding solution of -270000 is better than previous of -267750
#
# Cbc0038I Before mini branch and bound, 193 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 321 rows 360 columns, reduced to 192 rows 135 columns - 2 fixed gives 189, 132 - still too large
# Cbc0038I Full problem 321 rows 360 columns, reduced to 189 rows 132 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.51 seconds)
# Cbc0038I Round again with cutoff of -276718
# Cbc0038I Reduced cost fixing fixed 8 variables on major pass 5
# Cbc0038I Pass  81: suminf.   22.85659 (72) obj. -276718 iterations 5
# Cbc0038I Pass  82: suminf.   10.80015 (24) obj. -276718 iterations 81
# Cbc0038I Pass  83: suminf.   10.80015 (24) obj. -276718 iterations 11
# Cbc0038I Pass  84: suminf.    5.14296 (12) obj. -276718 iterations 39
# Cbc0038I Pass  85: suminf.    5.14296 (12) obj. -276718 iterations 20
# Cbc0038I Pass  86: suminf.    5.14296 (12) obj. -276718 iterations 64
# Cbc0038I Pass  87: suminf.    5.14296 (12) obj. -276718 iterations 34
# Cbc0038I Pass  88: suminf.    5.14296 (12) obj. -276718 iterations 74
# Cbc0038I Pass  89: suminf.    4.48578 (11) obj. -276718 iterations 114
# Cbc0038I Pass  90: suminf.    4.14296 (10) obj. -276718 iterations 65
# Cbc0038I Pass  91: suminf.    3.98222 (8) obj. -276718 iterations 124
# Cbc0038I Pass  92: suminf.    3.98222 (8) obj. -276718 iterations 58
# Cbc0038I Pass  93: suminf.    3.97867 (11) obj. -276718 iterations 141
# Cbc0038I Pass  94: suminf.    3.97867 (11) obj. -276718 iterations 9
# Cbc0038I Pass  95: suminf.    4.97511 (10) obj. -276718 iterations 61
# Cbc0038I Pass  96: suminf.    4.97511 (10) obj. -276718 iterations 28
# Cbc0038I Pass  97: suminf.    9.04800 (32) obj. -276718 iterations 87
# Cbc0038I Pass  98: suminf.    5.10011 (12) obj. -276718 iterations 64
# Cbc0038I Pass  99: suminf.    5.10011 (12) obj. -276718 iterations 25
# Cbc0038I Pass 100: suminf.    4.35722 (10) obj. -276718 iterations 68
# Cbc0038I Pass 101: suminf.    4.35722 (10) obj. -276718 iterations 29
# Cbc0038I Pass 102: suminf.    4.35722 (10) obj. -276718 iterations 113
# Cbc0038I Pass 103: suminf.    4.35722 (10) obj. -276718 iterations 20
# Cbc0038I Pass 104: suminf.   10.99644 (25) obj. -276718 iterations 78
# Cbc0038I Pass 105: suminf.    7.61433 (17) obj. -276718 iterations 78
# Cbc0038I Pass 106: suminf.    7.61433 (17) obj. -276718 iterations 13
# Cbc0038I Pass 107: suminf.    6.82463 (16) obj. -276718 iterations 87
# Cbc0038I Pass 108: suminf.    4.14296 (10) obj. -276718 iterations 99
# Cbc0038I Pass 109: suminf.    4.14296 (10) obj. -276718 iterations 14
# Cbc0038I Pass 110: suminf.    4.14296 (10) obj. -276718 iterations 110
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 187 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 321 rows 360 columns, reduced to 207 rows 144 columns - 8 fixed gives 117, 83 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.60 seconds)
# Cbc0038I After 0.60 seconds - Feasibility pump exiting with objective of -270000 - took 0.39 seconds
# Cbc0012I Integer solution of -270000 found by feasibility pump after 0 iterations and 0 nodes (0.60 seconds)
# Cbc0038I Full problem 321 rows 360 columns, reduced to 157 rows 101 columns
# Cbc0031I 7 added rows had average density of 60.857143
# Cbc0013I At root node, 39 cuts changed objective from -282500 to -270000 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 41 row cuts average 130.2 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 19 row cuts average 7.9 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 252 row cuts average 105.6 elements, 0 column cuts (0 active)  in 0.101 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -270000, took 454 iterations and 0 nodes (0.89 seconds)
# Cbc0035I Maximum depth 0, 44 variables fixed on reduced cost
# Total time (CPU seconds):       0.83   (Wallclock seconds):       0.90
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 513 (-765) rows, 360 (-360) columns and 2148 (-1266) elements
# Clp1000I sum of infeasibilities 4.33744e-07 - average 8.45505e-10, 114 fixed columns
# Coin0506I Presolve 319 (-194) rows, 205 (-155) columns and 1312 (-836) elements
# Clp0006I 0  Obj 313557.24 Dual inf 11760 (122)
# Clp0029I End of values pass after 205 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.901919e-05 ( 0.0014509595%) - largest zero change 2.5115664e-05
# Clp0000I Optimal - objective value 313593.75
# Clp0000I Optimal - objective value 313593.75
# Coin0511I After Postsolve, objective 313593.75, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 313593.75 Dual inf 204562.5 (47)
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.9019189e-05 ( 0.0014509595%) - largest zero change 2.5307018e-05
# Clp0000I Optimal - objective value 313593.75
# Clp0000I Optimal - objective value 313593.75
# Clp0000I Optimal - objective value 313593.75
# Coin0511I After Postsolve, objective 313593.75, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 313593.75 - 0 iterations time 0.102, Presolve 0.00, Idiot 0.09
#
# Starting MIP optimization
# optimal solution cost 277500.0 found
# (0, 1, 4)
# Cgl0003I 0 fixed, 0 tightened bounds, 291 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 291 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 246 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 222 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 143 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 80 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 67 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0004I processed model has 335 rows, 360 columns (360 integer (360 of which binary)) and 2080 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 1.184%
# Cgl0015I Clique Strengthening extended 1 cliques, 3 were dominated
# Cbc0038I Initial state - 7 integers unsatisfied sum - 3.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -266250 iterations 164
# Cbc0038I Solution found of -266250
# Cbc0038I Before mini branch and bound, 351 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 333 rows 360 columns, reduced to 13 rows 9 columns
# Cbc0038I Mini branch and bound improved solution from -266250 to -275250 (0.22 seconds)
# Cbc0038I Round again with cutoff of -276150
# Cbc0038I Reduced cost fixing fixed 51 variables on major pass 2
# Cbc0038I Pass   2: suminf.    2.40000 (8) obj. -276150 iterations 82
# Cbc0038I Pass   3: suminf.    1.40000 (5) obj. -276150 iterations 55
# Cbc0038I Pass   4: suminf.    1.40000 (5) obj. -276150 iterations 22
# Cbc0038I Pass   5: suminf.    1.05000 (3) obj. -276150 iterations 105
# Cbc0038I Pass   6: suminf.    1.50000 (3) obj. -277500 iterations 97
# Cbc0038I Pass   7: suminf.    1.05000 (3) obj. -276150 iterations 50
# Cbc0038I Pass   8: suminf.    1.05000 (3) obj. -276150 iterations 44
# Cbc0038I Pass   9: suminf.    1.05000 (3) obj. -276150 iterations 97
# Cbc0038I Pass  10: suminf.    1.05000 (3) obj. -276150 iterations 33
# Cbc0038I Pass  11: suminf.    1.05000 (3) obj. -276150 iterations 95
# Cbc0038I Pass  12: suminf.    1.75000 (5) obj. -276150 iterations 81
# Cbc0038I Pass  13: suminf.    1.75000 (5) obj. -276150 iterations 92
# Cbc0038I Pass  14: suminf.    1.75000 (5) obj. -276150 iterations 132
# Cbc0038I Pass  15: suminf.    1.75000 (5) obj. -276150 iterations 28
# Cbc0038I Pass  16: suminf.    1.75000 (5) obj. -276150 iterations 121
# Cbc0038I Pass  17: suminf.    3.40000 (11) obj. -276150 iterations 120
# Cbc0038I Pass  18: suminf.    1.80000 (9) obj. -276150 iterations 74
# Cbc0038I Pass  19: suminf.    1.75000 (5) obj. -276150 iterations 119
# Cbc0038I Pass  20: suminf.    1.40000 (3) obj. -276150 iterations 14
# Cbc0038I Pass  21: suminf.    1.40000 (3) obj. -276150 iterations 135
# Cbc0038I Pass  22: suminf.    1.40000 (3) obj. -276150 iterations 47
# Cbc0038I Pass  23: suminf.    1.40000 (3) obj. -276150 iterations 140
# Cbc0038I Pass  24: suminf.    2.65000 (10) obj. -276150 iterations 99
# Cbc0038I Pass  25: suminf.    1.50000 (3) obj. -277500 iterations 84
# Cbc0038I Pass  26: suminf.    1.05000 (3) obj. -276150 iterations 46
# Cbc0038I Pass  27: suminf.    1.05000 (3) obj. -276150 iterations 36
# Cbc0038I Pass  28: suminf.    1.05000 (3) obj. -276150 iterations 101
# Cbc0038I Pass  29: suminf.    1.05000 (3) obj. -276150 iterations 37
# Cbc0038I Pass  30: suminf.    1.05000 (3) obj. -276150 iterations 102
# Cbc0038I Pass  31: suminf.    2.50000 (7) obj. -276150 iterations 92
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 311 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 333 rows 360 columns, reduced to 44 rows 41 columns
# Cbc0038I Mini branch and bound did not improve solution (0.31 seconds)
# Cbc0038I After 0.31 seconds - Feasibility pump exiting with objective of -275250 - took 0.10 seconds
# Cbc0012I Integer solution of -275250 found by feasibility pump after 0 iterations and 0 nodes (0.31 seconds)
# Cbc0012I Integer solution of -277500 found by DiveCoefficient after 0 iterations and 0 nodes (0.32 seconds)
# Cbc0001I Search completed - best objective -277500, took 0 iterations and 0 nodes (0.32 seconds)
# Cbc0035I Maximum depth 0, 51 variables fixed on reduced cost
# Total time (CPU seconds):       0.30   (Wallclock seconds):       0.35
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 531 (-747) rows, 372 (-348) columns and 2286 (-1257) elements
# Clp1000I sum of infeasibilities 1.86736e-07 - average 3.51668e-10, 103 fixed columns
# Coin0506I Presolve 375 (-156) rows, 224 (-148) columns and 1603 (-683) elements
# Clp0006I 0  Obj 291907.34 Dual inf 15660 (155)
# Clp0029I End of values pass after 224 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.896648e-05 ( 0.001448324%) - largest zero change 2.9394864e-05
# Clp0000I Optimal - objective value 291937.5
# Clp0000I Optimal - objective value 291937.5
# Coin0511I After Postsolve, objective 291937.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 291937.5 Dual inf 49650 (14)
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.5183845e-05 ( 0.0012591923%) - largest zero change 2.9019187e-05
# Clp0000I Optimal - objective value 291937.5
# Clp0000I Optimal - objective value 291937.5
# Clp0000I Optimal - objective value 291937.5
# Coin0511I After Postsolve, objective 291937.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 291937.5 - 0 iterations time 0.102, Presolve 0.00, Idiot 0.09
#
# Starting MIP optimization
# optimal solution cost 270000.0 found
# (0, 1, 5)
# Cgl0003I 0 fixed, 0 tightened bounds, 309 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 309 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 281 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 272 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 180 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 145 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 100 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 70 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 32 strengthened rows, 0 substitutions
# Cgl0004I processed model has 391 rows, 372 columns (372 integer (372 of which binary)) and 2788 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 1.251%
# Cgl0015I Clique Strengthening extended 29 cliques, 83 were dominated
# Cbc0038I Initial state - 81 integers unsatisfied sum - 40.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -9000 iterations 212
# Cbc0038I Solution found of -9000
# Cbc0038I Rounding solution of -180750 is better than previous of -9000
#
# Cbc0038I Before mini branch and bound, 287 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 337 rows 372 columns, reduced to 89 rows 64 columns
# Cbc0038I Mini branch and bound improved solution from -180750 to -264750 (0.25 seconds)
# Cbc0038I Round again with cutoff of -266700
# Cbc0038I Pass   2: suminf.   31.60000 (67) obj. -266700 iterations 200
# Cbc0038I Pass   3: suminf.   29.80000 (62) obj. -266700 iterations 8
# Cbc0038I Pass   4: suminf.   29.40000 (60) obj. -266700 iterations 10
# Cbc0038I Pass   5: suminf.   22.00000 (52) obj. -266700 iterations 55
# Cbc0038I Pass   6: suminf.   13.36667 (29) obj. -266700 iterations 88
# Cbc0038I Pass   7: suminf.   13.36667 (29) obj. -266700 iterations 9
# Cbc0038I Pass   8: suminf.   13.36667 (29) obj. -266700 iterations 24
# Cbc0038I Pass   9: suminf.   12.54074 (42) obj. -266700 iterations 87
# Cbc0038I Pass  10: suminf.    2.44444 (5) obj. -266700 iterations 87
# Cbc0038I Solution found of -270000
# Cbc0038I Before mini branch and bound, 244 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 337 rows 372 columns, reduced to 136 rows 103 columns
# Cbc0038I Mini branch and bound did not improve solution (0.33 seconds)
# Cbc0038I Round again with cutoff of -272100
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 3
# Cbc0038I Pass  11: suminf.   35.00000 (76) obj. -272100 iterations 10
# Cbc0038I Pass  12: suminf.    7.95000 (23) obj. -272100 iterations 95
# Cbc0038I Pass  13: suminf.    7.95000 (23) obj. -272100 iterations 28
# Cbc0038I Pass  14: suminf.    6.90000 (23) obj. -272100 iterations 92
# Cbc0038I Pass  15: suminf.    6.90000 (23) obj. -272100 iterations 27
# Cbc0038I Pass  16: suminf.    7.95000 (23) obj. -272100 iterations 89
# Cbc0038I Pass  17: suminf.    7.35000 (21) obj. -272100 iterations 89
# Cbc0038I Pass  18: suminf.    6.90000 (22) obj. -272100 iterations 78
# Cbc0038I Pass  19: suminf.    6.90000 (22) obj. -272100 iterations 6
# Cbc0038I Pass  20: suminf.    6.90000 (22) obj. -272100 iterations 20
# Cbc0038I Pass  21: suminf.    6.90000 (22) obj. -272100 iterations 54
# Cbc0038I Pass  22: suminf.    6.90000 (22) obj. -272100 iterations 51
# Cbc0038I Pass  23: suminf.    8.92500 (21) obj. -272100 iterations 106
# Cbc0038I Pass  24: suminf.    7.50000 (25) obj. -272100 iterations 40
# Cbc0038I Pass  25: suminf.    7.50000 (25) obj. -272100 iterations 29
# Cbc0038I Pass  26: suminf.    7.50000 (25) obj. -272100 iterations 5
# Cbc0038I Pass  27: suminf.    7.50000 (25) obj. -272100 iterations 11
# Cbc0038I Pass  28: suminf.    9.67500 (37) obj. -272100 iterations 62
# Cbc0038I Pass  29: suminf.    7.30000 (22) obj. -272100 iterations 52
# Cbc0038I Pass  30: suminf.    6.90000 (23) obj. -272100 iterations 25
# Cbc0038I Pass  31: suminf.    7.95000 (23) obj. -272100 iterations 88
# Cbc0038I Pass  32: suminf.    7.95000 (23) obj. -272100 iterations 47
# Cbc0038I Pass  33: suminf.    6.90000 (23) obj. -272100 iterations 119
# Cbc0038I Pass  34: suminf.    7.35000 (22) obj. -272100 iterations 61
# Cbc0038I Pass  35: suminf.    7.35000 (24) obj. -272100 iterations 78
# Cbc0038I Pass  36: suminf.    8.55000 (26) obj. -272100 iterations 54
# Cbc0038I Pass  37: suminf.    8.55000 (25) obj. -272100 iterations 32
# Cbc0038I Pass  38: suminf.    8.10000 (23) obj. -272100 iterations 84
# Cbc0038I Pass  39: suminf.    7.30000 (22) obj. -272100 iterations 78
# Cbc0038I Pass  40: suminf.    6.90000 (23) obj. -272100 iterations 37
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 221 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 337 rows 372 columns, reduced to 166 rows 122 columns
# Cbc0038I Mini branch and bound did not improve solution (0.47 seconds)
# Cbc0038I After 0.47 seconds - Feasibility pump exiting with objective of -270000 - took 0.22 seconds
# Cbc0012I Integer solution of -270000 found by feasibility pump after 0 iterations and 0 nodes (0.47 seconds)
# Cbc0038I Full problem 337 rows 372 columns, reduced to 99 rows 73 columns
# Cbc0031I 6 added rows had average density of 56.166667
# Cbc0013I At root node, 33 cuts changed objective from -277500 to -270000 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 8 row cuts average 81.9 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 13 row cuts average 12.5 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 99 row cuts average 127.6 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -270000, took 130 iterations and 0 nodes (0.57 seconds)
# Cbc0035I Maximum depth 0, 51 variables fixed on reduced cost
# Total time (CPU seconds):       0.53   (Wallclock seconds):       0.59
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 513 (-765) rows, 354 (-366) columns and 2160 (-1383) elements
# Clp1000I sum of infeasibilities 4.0001e-07 - average 7.79746e-10, 80 fixed columns
# Coin0506I Presolve 373 (-140) rows, 228 (-126) columns and 1673 (-487) elements
# Clp0006I 0  Obj 278292.68 Dual inf 13987.5 (148)
# Clp0029I End of values pass after 228 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.5191573e-05 ( 0.0012595786%) - largest zero change 2.3587553e-05
# Clp0000I Optimal - objective value 278383.93
# Clp0000I Optimal - objective value 278383.93
# Coin0511I After Postsolve, objective 278383.93, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 278383.93 Dual inf 5390.625 (4)
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 1.6810286e-05 ( 0.00084051428%) - largest zero change 2.6218914e-05
# Clp0000I Optimal - objective value 278383.93
# Clp0000I Optimal - objective value 278383.93
# Clp0000I Optimal - objective value 278383.93
# Coin0511I After Postsolve, objective 278383.93, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 278383.9286 - 0 iterations time 0.092, Presolve 0.00, Idiot 0.09
#
# Starting MIP optimization
# optimal solution cost 247500.0 found
# (0, 1, 6)
# Cgl0003I 0 fixed, 0 tightened bounds, 291 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 291 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 246 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 231 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 157 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 105 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 82 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 37 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0004I processed model has 335 rows, 354 columns (354 integer (354 of which binary)) and 2156 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 1.225%
# Cgl0015I Clique Strengthening extended 9 cliques, 27 were dominated
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -247500
# Cbc0038I Before mini branch and bound, 354 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.18 seconds)
# Cbc0038I After 0.18 seconds - Feasibility pump exiting with objective of -247500 - took 0.00 seconds
# Cbc0012I Integer solution of -247500 found by feasibility pump after 0 iterations and 0 nodes (0.18 seconds)
# Cbc0001I Search completed - best objective -247500, took 0 iterations and 0 nodes (0.18 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.18   (Wallclock seconds):       0.19
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 519 (-759) rows, 366 (-354) columns and 2124 (-1155) elements
# Clp1000I sum of infeasibilities 1.22266e-07 - average 2.3558e-10, 42 fixed columns
# Coin0506I Presolve 424 (-95) rows, 278 (-88) columns and 1889 (-235) elements
# Clp0006I 0  Obj 269886.33 Dual inf 13005 (156)
# Clp0029I End of values pass after 278 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.8168907e-05 ( 0.0014084453%) - largest zero change 1.5710329e-05
# Clp0000I Optimal - objective value 269888.44
# Clp0000I Optimal - objective value 269888.44
# Coin0511I After Postsolve, objective 269888.44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 269888.44 Dual inf 1798.2339 (2)
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 1.9231692e-05 ( 0.00096158459%) - largest zero change 2.2680446e-05
# Clp0000I Optimal - objective value 269888.44
# Clp0000I Optimal - objective value 269888.44
# Clp0000I Optimal - objective value 269888.44
# Coin0511I After Postsolve, objective 269888.44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 269888.4419 - 0 iterations time 0.112, Presolve 0.00, Idiot 0.11
#
# Starting MIP optimization
# optimal solution cost 222000.0 found
# (0, 1, 7)
# Cgl0003I 0 fixed, 0 tightened bounds, 297 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 297 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 233 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 228 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 125 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 86 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20 strengthened rows, 0 substitutions
# Cgl0004I processed model has 334 rows, 366 columns (366 integer (366 of which binary)) and 1967 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 1.125%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 107 integers unsatisfied sum - 35.6667
# Cbc0038I Pass   1: suminf.    2.50000 (5) obj. -219000 iterations 191
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. -214500 iterations 26
# Cbc0038I Solution found of -214500
# Cbc0038I Before mini branch and bound, 254 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 334 rows 366 columns, reduced to 113 rows 78 columns
# Cbc0038I Mini branch and bound improved solution from -214500 to -218550 (0.21 seconds)
# Cbc0038I Round again with cutoff of -219962
# Cbc0038I Pass   3: suminf.    2.74062 (8) obj. -219962 iterations 21
# Cbc0038I Pass   4: suminf.    1.36562 (3) obj. -219962 iterations 77
# Cbc0038I Pass   5: suminf.    1.36562 (3) obj. -219962 iterations 3
# Cbc0038I Pass   6: suminf.    1.36562 (3) obj. -219962 iterations 73
# Cbc0038I Pass   7: suminf.    1.36562 (3) obj. -219962 iterations 71
# Cbc0038I Pass   8: suminf.    1.36562 (3) obj. -219962 iterations 64
# Cbc0038I Pass   9: suminf.    5.87500 (15) obj. -219962 iterations 130
# Cbc0038I Pass  10: suminf.    1.99583 (6) obj. -219962 iterations 90
# Cbc0038I Pass  11: suminf.    1.99583 (6) obj. -219962 iterations 47
# Cbc0038I Pass  12: suminf.    1.99583 (6) obj. -219962 iterations 75
# Cbc0038I Pass  13: suminf.    1.99583 (6) obj. -219962 iterations 45
# Cbc0038I Pass  14: suminf.    1.99583 (6) obj. -219962 iterations 79
# Cbc0038I Pass  15: suminf.    4.01222 (18) obj. -219962 iterations 126
# Cbc0038I Pass  16: suminf.    1.76543 (4) obj. -219962 iterations 95
# Cbc0038I Pass  17: suminf.    1.36562 (3) obj. -219962 iterations 43
# Cbc0038I Pass  18: suminf.    1.36562 (3) obj. -219962 iterations 53
# Cbc0038I Pass  19: suminf.    1.36562 (3) obj. -219962 iterations 35
# Cbc0038I Pass  20: suminf.    1.36562 (3) obj. -219962 iterations 41
# Cbc0038I Pass  21: suminf.    4.36806 (11) obj. -219962 iterations 133
# Cbc0038I Pass  22: suminf.    3.20139 (10) obj. -219962 iterations 73
# Cbc0038I Pass  23: suminf.    2.20139 (8) obj. -219962 iterations 24
# Cbc0038I Pass  24: suminf.    2.20139 (8) obj. -219962 iterations 11
# Cbc0038I Pass  25: suminf.    1.92083 (6) obj. -219962 iterations 110
# Cbc0038I Pass  26: suminf.    1.92083 (6) obj. -219962 iterations 36
# Cbc0038I Pass  27: suminf.    1.92083 (6) obj. -219962 iterations 59
# Cbc0038I Pass  28: suminf.    1.92083 (6) obj. -219962 iterations 47
# Cbc0038I Pass  29: suminf.    1.92083 (6) obj. -219962 iterations 2
# Cbc0038I Pass  30: suminf.    1.92083 (6) obj. -219962 iterations 72
# Cbc0038I Pass  31: suminf.    1.92083 (6) obj. -219962 iterations 43
# Cbc0038I Pass  32: suminf.    1.92083 (6) obj. -219962 iterations 12
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 232 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 334 rows 366 columns, reduced to 136 rows 103 columns
# Cbc0038I Mini branch and bound did not improve solution (0.43 seconds)
# Cbc0038I After 0.43 seconds - Feasibility pump exiting with objective of -218550 - took 0.22 seconds
# Cbc0012I Integer solution of -218550 found by feasibility pump after 0 iterations and 0 nodes (0.43 seconds)
# Cbc0038I Full problem 334 rows 366 columns, reduced to 105 rows 73 columns
# Cbc0012I Integer solution of -222000 found by DiveCoefficient after 203 iterations and 0 nodes (0.59 seconds)
# Cbc0031I 7 added rows had average density of 68.714286
# Cbc0013I At root node, 7 cuts changed objective from -232000 to -222000 in 7 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 19 row cuts average 107.1 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 7 row cuts average 10.1 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 190 row cuts average 95.9 elements, 0 column cuts (0 active)  in 0.044 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -222000, took 203 iterations and 0 nodes (0.59 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.56   (Wallclock seconds):       0.62
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 540 (-738) rows, 372 (-348) columns and 2466 (-1356) elements
# Clp1000I sum of infeasibilities 6.83245e-07 - average 1.26527e-09, 100 fixed columns
# Coin0506I Presolve 354 (-186) rows, 227 (-145) columns and 1538 (-928) elements
# Clp0006I 0  Obj 293430.14 Dual inf 14295 (131)
# Clp0029I End of values pass after 227 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.9822462e-05 ( 0.0014911231%) - largest zero change 2.0503357e-05
# Clp0000I Optimal - objective value 293437.5
# Clp0000I Optimal - objective value 293437.5
# Coin0511I After Postsolve, objective 293437.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 293437.5 Dual inf 127687.5 (30)
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.9283558e-05 ( 0.0014641779%) - largest zero change 2.9576128e-05
# Clp0000I Optimal - objective value 293437.5
# Clp0000I Optimal - objective value 293437.5
# Clp0000I Optimal - objective value 293437.5
# Coin0511I After Postsolve, objective 293437.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 293437.5 - 0 iterations time 0.102, Presolve 0.00, Idiot 0.10
#
# Starting MIP optimization
# optimal solution cost 262500.0 found
# (0, 1, 8)
# Cgl0003I 0 fixed, 0 tightened bounds, 300 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 299 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 278 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 266 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 230 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 195 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 150 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 120 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 73 strengthened rows, 0 substitutions
# Cgl0004I processed model has 400 rows, 372 columns (372 integer (372 of which binary)) and 3092 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 1.395%
# Cgl0015I Clique Strengthening extended 38 cliques, 107 were dominated
# Cbc0038I Initial state - 72 integers unsatisfied sum - 36
# ...
# Clp0029I End of values pass after 103 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000004 - largest nonzero change 2.9669817e-05 ( 0.0014834909%) - largest zero change 2.6331912e-05
# Clp0000I Optimal - objective value 173625
# Clp0000I Optimal - objective value 173625
# Coin0511I After Postsolve, objective 173625, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 173625 Dual inf 230175 (31)
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.9822462e-05 ( 0.0014911231%) - largest zero change 2.9522154e-05
# Clp0000I Optimal - objective value 173625
# Clp0000I Optimal - objective value 173625
# Clp0000I Optimal - objective value 173625
# Coin0511I After Postsolve, objective 173625, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 173625 - 0 iterations time 0.072, Presolve 0.00, Idiot 0.06
#
# Starting MIP optimization
# optimal solution cost 171750.0 found
# (5, 6, 8)
# Cgl0003I 0 fixed, 0 tightened bounds, 227 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 208 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 173 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 140 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 115 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 92 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 76 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 44 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24 strengthened rows, 0 substitutions
# Cgl0004I processed model has 214 rows, 241 columns (241 integer (241 of which binary)) and 1696 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 1.716%
# Cgl0015I Clique Strengthening extended 11 cliques, 36 were dominated
# Cbc0038I Initial state - 4 integers unsatisfied sum - 2
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -171750 iterations 62
# Cbc0038I Solution found of -171750
# Cbc0038I Before mini branch and bound, 236 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.12 seconds)
# Cbc0038I After 0.12 seconds - Feasibility pump exiting with objective of -171750 - took 0.00 seconds
# Cbc0012I Integer solution of -171750 found by feasibility pump after 0 iterations and 0 nodes (0.12 seconds)
# Cbc0001I Search completed - best objective -171750, took 0 iterations and 0 nodes (0.12 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.12   (Wallclock seconds):       0.13
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 306 (-972) rows, 240 (-480) columns and 1455 (-2010) elements
# Clp1000I sum of infeasibilities 6.53429e-07 - average 2.13539e-09, 180 fixed columns
# Coin0506I Presolve 72 (-234) rows, 60 (-180) columns and 222 (-1233) elements
# Clp0006I 0  Obj 402499.99 Dual inf 8325 (24)
# Clp0029I End of values pass after 60 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000008 - largest nonzero change 2.0503364e-05 ( 0.0010251682%) - largest zero change 2.9522154e-05
# Clp0000I Optimal - objective value 402500
# Clp0000I Optimal - objective value 402500
# Coin0511I After Postsolve, objective 402500, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 402500 Dual inf 1077500 (133)
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.901919e-05 ( 0.0014509595%) - largest zero change 2.9522154e-05
# Clp0000I Optimal - objective value 402500
# Clp0000I Optimal - objective value 402500
# Clp0000I Optimal - objective value 402500
# Coin0511I After Postsolve, objective 402500, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 402500 - 0 iterations time 0.042, Presolve 0.00, Idiot 0.04
#
# Starting MIP optimization
# optimal solution cost 381750.0 found
# (5, 7, 8)
# Cgl0003I 0 fixed, 0 tightened bounds, 207 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 207 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 195 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 191 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 172 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 145 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 120 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 36 strengthened rows, 0 substitutions
# Cgl0004I processed model has 195 rows, 240 columns (240 integer (240 of which binary)) and 1877 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 1.759%
# Cgl0015I Clique Strengthening extended 20 cliques, 61 were dominated
# Cbc0038I Initial state - 40 integers unsatisfied sum - 15.3333
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -150000 iterations 123
# Cbc0038I Solution found of -150000
# Cbc0038I Rounding solution of -215025 is better than previous of -150000
#
# Cbc0038I Before mini branch and bound, 196 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 154 rows 240 columns, reduced to 53 rows 43 columns
# Cbc0038I Mini branch and bound improved solution from -215025 to -375000 (0.14 seconds)
# Cbc0038I Round again with cutoff of -377817
# Cbc0038I Pass   2: suminf.    2.29574 (11) obj. -377817 iterations 63
# Cbc0038I Pass   3: suminf.    0.56350 (3) obj. -377817 iterations 28
# Cbc0038I Pass   4: suminf.    0.56350 (3) obj. -377817 iterations 49
# Cbc0038I Pass   5: suminf.    0.56350 (3) obj. -377817 iterations 17
# Cbc0038I Pass   6: suminf.    0.56350 (3) obj. -377817 iterations 56
# Cbc0038I Pass   7: suminf.    1.78609 (11) obj. -377817 iterations 72
# Cbc0038I Pass   8: suminf.    1.45661 (13) obj. -377817 iterations 66
# Cbc0038I Pass   9: suminf.    0.13208 (3) obj. -377817 iterations 27
# Cbc0038I Pass  10: suminf.    0.13208 (3) obj. -377817 iterations 10
# Cbc0038I Pass  11: suminf.    1.33333 (4) obj. -380025 iterations 59
# Cbc0038I Pass  12: suminf.    1.52956 (4) obj. -377817 iterations 65
# Cbc0038I Pass  13: suminf.    2.90343 (10) obj. -377817 iterations 54
# Cbc0038I Pass  14: suminf.    1.33333 (4) obj. -380025 iterations 72
# Cbc0038I Pass  15: suminf.    1.52956 (4) obj. -377817 iterations 53
# Cbc0038I Pass  16: suminf.    1.84133 (10) obj. -377817 iterations 72
# Cbc0038I Pass  17: suminf.    1.33333 (4) obj. -378000 iterations 62
# Cbc0038I Pass  18: suminf.    1.34956 (4) obj. -377817 iterations 50
# Cbc0038I Pass  19: suminf.    1.36578 (8) obj. -377817 iterations 72
# Cbc0038I Pass  20: suminf.    1.33333 (4) obj. -378000 iterations 56
# Cbc0038I Pass  21: suminf.    1.34956 (4) obj. -377817 iterations 40
# Cbc0038I Pass  22: suminf.    7.79403 (17) obj. -377817 iterations 85
# Cbc0038I Pass  23: suminf.    3.69822 (11) obj. -377817 iterations 54
# Cbc0038I Pass  24: suminf.    0.46958 (3) obj. -377817 iterations 34
# Cbc0038I Pass  25: suminf.    0.46958 (3) obj. -377817 iterations 10
# Cbc0038I Pass  26: suminf.    0.46958 (3) obj. -377817 iterations 42
# Cbc0038I Pass  27: suminf.    0.46958 (3) obj. -377817 iterations 20
# Cbc0038I Pass  28: suminf.    0.46958 (3) obj. -377817 iterations 39
# Cbc0038I Pass  29: suminf.    0.78264 (5) obj. -377817 iterations 53
# Cbc0038I Pass  30: suminf.    0.46958 (3) obj. -377817 iterations 47
# Cbc0038I Pass  31: suminf.    0.46958 (3) obj. -377817 iterations 38
# Cbc0038I Rounding solution of -379050 is better than previous of -375000
#
# Cbc0038I Before mini branch and bound, 161 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 154 rows 240 columns, reduced to 83 rows 79 columns
# Cbc0038I Mini branch and bound did not improve solution (0.22 seconds)
# Cbc0038I Round again with cutoff of -383800
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 3
# Cbc0038I Pass  31: suminf.    7.47407 (23) obj. -383800 iterations 15
# Cbc0038I Pass  32: suminf.    2.64333 (7) obj. -383800 iterations 49
# Cbc0038I Pass  33: suminf.    1.91000 (6) obj. -383800 iterations 14
# Cbc0038I Pass  34: suminf.    1.91000 (6) obj. -383800 iterations 4
# Cbc0038I Pass  35: suminf.    1.91818 (15) obj. -383800 iterations 68
# Cbc0038I Pass  36: suminf.    1.73000 (6) obj. -383800 iterations 40
# Cbc0038I Pass  37: suminf.    1.35500 (3) obj. -383800 iterations 9
# Cbc0038I Pass  38: suminf.    1.35500 (3) obj. -383800 iterations 63
# Cbc0038I Pass  39: suminf.    1.35500 (3) obj. -383800 iterations 28
# Cbc0038I Pass  40: suminf.    1.35500 (3) obj. -383800 iterations 48
# Cbc0038I Pass  41: suminf.    5.12453 (19) obj. -383800 iterations 80
# Cbc0038I Pass  42: suminf.    1.35500 (3) obj. -383800 iterations 58
# Cbc0038I Pass  43: suminf.    1.35500 (3) obj. -383800 iterations 0
# Cbc0038I Pass  44: suminf.    1.35500 (3) obj. -383800 iterations 57
# Cbc0038I Pass  45: suminf.    1.35500 (3) obj. -383800 iterations 24
# Cbc0038I Pass  46: suminf.    1.35500 (3) obj. -383800 iterations 48
# Cbc0038I Pass  47: suminf.    3.68125 (17) obj. -383800 iterations 97
# Cbc0038I Pass  48: suminf.    3.29056 (11) obj. -383800 iterations 58
# Cbc0038I Pass  49: suminf.    2.87534 (19) obj. -383800 iterations 20
# Cbc0038I Pass  50: suminf.    2.87534 (19) obj. -383800 iterations 15
# Cbc0038I Pass  51: suminf.    2.25833 (5) obj. -383800 iterations 33
# Cbc0038I Pass  52: suminf.    2.25833 (5) obj. -383800 iterations 19
# Cbc0038I Pass  53: suminf.    1.48389 (7) obj. -383800 iterations 80
# Cbc0038I Pass  54: suminf.    2.25833 (5) obj. -383800 iterations 59
# Cbc0038I Pass  55: suminf.    1.35500 (3) obj. -383800 iterations 5
# Cbc0038I Pass  56: suminf.    2.36667 (9) obj. -383800 iterations 70
# Cbc0038I Pass  57: suminf.    1.85802 (4) obj. -383800 iterations 47
# Cbc0038I Pass  58: suminf.    1.35500 (3) obj. -383800 iterations 58
# Cbc0038I Pass  59: suminf.    1.35500 (3) obj. -383800 iterations 46
# Cbc0038I Pass  60: suminf.    1.35500 (3) obj. -383800 iterations 27
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 159 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 154 rows 240 columns, reduced to 83 rows 81 columns
# Cbc0038I Mini branch and bound improved solution from -379050 to -379725 (0.29 seconds)
# Cbc0038I Round again with cutoff of -389410
# Cbc0038I Reduced cost fixing fixed 4 variables on major pass 4
# Cbc0038I Pass  60: suminf.   11.10111 (25) obj. -389410 iterations 20
# Cbc0038I Pass  61: suminf.    3.07111 (10) obj. -389410 iterations 52
# Cbc0038I Pass  62: suminf.    3.07111 (10) obj. -389410 iterations 19
# Cbc0038I Pass  63: suminf.    3.07111 (10) obj. -389410 iterations 13
# Cbc0038I Pass  64: suminf.    3.07111 (10) obj. -389410 iterations 10
# Cbc0038I Pass  65: suminf.    3.07111 (10) obj. -389410 iterations 3
# Cbc0038I Pass  66: suminf.    5.85455 (34) obj. -389410 iterations 79
# Cbc0038I Pass  67: suminf.    3.91951 (9) obj. -389410 iterations 73
# Cbc0038I Pass  68: suminf.    2.94089 (7) obj. -389410 iterations 27
# Cbc0038I Pass  69: suminf.    2.82267 (6) obj. -389410 iterations 35
# Cbc0038I Pass  70: suminf.    2.82267 (6) obj. -389410 iterations 3
# Cbc0038I Pass  71: suminf.    5.93833 (22) obj. -389410 iterations 73
# Cbc0038I Pass  72: suminf.    5.08667 (12) obj. -389410 iterations 34
# Cbc0038I Pass  73: suminf.    5.08667 (12) obj. -389410 iterations 5
# Cbc0038I Pass  74: suminf.    7.88862 (32) obj. -389410 iterations 79
# Cbc0038I Pass  75: suminf.    2.62700 (6) obj. -389410 iterations 78
# Cbc0038I Pass  76: suminf.    2.58556 (6) obj. -389410 iterations 50
# Cbc0038I Pass  77: suminf.    2.58556 (6) obj. -389410 iterations 1
# Cbc0038I Pass  78: suminf.    3.19821 (13) obj. -389410 iterations 89
# Cbc0038I Pass  79: suminf.    2.80267 (6) obj. -389410 iterations 53
# Cbc0038I Pass  80: suminf.    2.58556 (6) obj. -389410 iterations 35
# Cbc0038I Pass  81: suminf.    5.38203 (15) obj. -389410 iterations 77
# Cbc0038I Pass  82: suminf.    2.58556 (6) obj. -389410 iterations 69
# Cbc0038I Pass  83: suminf.    2.58556 (6) obj. -389410 iterations 9
# Cbc0038I Pass  84: suminf.    2.58556 (6) obj. -389410 iterations 43
# Cbc0038I Pass  85: suminf.    2.58556 (6) obj. -389410 iterations 29
# Cbc0038I Pass  86: suminf.    2.58556 (6) obj. -389410 iterations 57
# Cbc0038I Pass  87: suminf.    6.74380 (19) obj. -389410 iterations 91
# Cbc0038I Pass  88: suminf.    4.93500 (31) obj. -389410 iterations 71
# Cbc0038I Pass  89: suminf.    4.22500 (30) obj. -389410 iterations 9
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 157 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 154 rows 240 columns, reduced to 87 rows 83 columns
# Cbc0038I Mini branch and bound did not improve solution (0.35 seconds)
# Cbc0038I After 0.35 seconds - Feasibility pump exiting with objective of -379725 - took 0.20 seconds
# Cbc0012I Integer solution of -379725 found by feasibility pump after 0 iterations and 0 nodes (0.35 seconds)
# Cbc0038I Full problem 154 rows 240 columns, reduced to 56 rows 43 columns
# Cbc0012I Integer solution of -381750 found by DiveCoefficient after 228 iterations and 0 nodes (0.53 seconds)
# Cbc0031I 14 added rows had average density of 42.642857
# Cbc0013I At root node, 14 cuts changed objective from -402500 to -381750 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 46 row cuts average 46.8 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 29.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 4 row cuts average 8.2 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 61 row cuts average 48.3 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is 1
# Cbc0014I Cut generator 8 (ZeroHalf) - 3 row cuts average 24.3 elements, 0 column cuts (0 active)  in 0.060 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -381750, took 228 iterations and 0 nodes (0.53 seconds)
# Cbc0035I Maximum depth 0, 38 variables fixed on reduced cost
# Total time (CPU seconds):       0.45   (Wallclock seconds):       0.56
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 327 (-951) rows, 246 (-474) columns and 1797 (-2211) elements
# Clp1000I sum of infeasibilities 5.23719e-07 - average 1.60159e-09, 186 fixed columns
# Coin0506I Presolve 72 (-255) rows, 60 (-186) columns and 222 (-1575) elements
# Clp0006I 0  Obj 402499.99 Dual inf 8325 (24)
# Clp0029I End of values pass after 60 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000008 - largest nonzero change 2.0503364e-05 ( 0.0010251682%) - largest zero change 2.9522154e-05
# Clp0000I Optimal - objective value 402500
# Clp0000I Optimal - objective value 402500
# Coin0511I After Postsolve, objective 402500, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 402500 Dual inf 1320750 (136)
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.9283559e-05 ( 0.0014641779%) - largest zero change 2.9522154e-05
# Clp0000I Optimal - objective value 402500
# Clp0000I Optimal - objective value 402500
# Clp0000I Optimal - objective value 402500
# Coin0511I After Postsolve, objective 402500, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 402500 - 0 iterations time 0.042, Presolve 0.00, Idiot 0.04
#
# Starting MIP optimization
# optimal solution cost 382500.0 found
# [5, 7, 8]

# %% [markdown]
# # EXPÉRIMENTATION SUR L'HORIZON DE TEMPS

# %% [markdown]
# ### Modification de l'horizon de temps d'une instance la classe data

# %%
def modif_horizon( datal , datat, n ):
    data = Data(datal, datat)
    data2 = Data(datal, datat)
    data2.horizon = data2.horizon * n
    for i in range ( data2.nblegumes ):
        V = data.price[i]
        for j in range (n-1):
            for k in V:
                data2.price[i]+=[k]
    data2.price[data2.nblegumes]=np.zeros(data2.horizon)
    data2.price[data2.nblegumes+1]=np.zeros(data2.horizon)
    return data2

# %% [markdown]
# ### Méthode de résolution linéaire pour un horizon modifié ( Il fallait étendre les contraintes de jachère et de fertilisation )

# %%
def build_model_bis ( Data , n):
    model = Model(name = "solver", solver_name=CBC)
    #creating variables
    z=[[[model.add_var(name='z'+str(p)+'_'+str(l)+'_'+str(t),var_type=BINARY) for t in range (Data.horizon) ]for l in range (Data.nblegumes+2)]for p in range (Data.nbparcelle)]
    x=[[[model.add_var(name='x'+str(p)+'_'+str(l)+'_'+str(t),var_type=BINARY) for t in range (Data.horizon) ]for l in range (Data.nblegumes+2)]for p in range (Data.nbparcelle)]
    z = np.array(z)
    x = np.array(x)
    #objective
    model.objective = maximize(xsum(z[p][l][t]*Data.surface[p]*Data.price[l][t] for p in range(Data.nbparcelle) for l in range(Data.nblegumes+2) for t in range(Data.horizon) if (abs(Data.price[l][t])>1e-6) ) ) 
    #constraint
    #fertilisation
    for p in range(Data.nbparcelle):
        for k in range (0,n):
            model.add_constr(xsum(z[p][Data.nblegumes][t] for t in range (k*(Data.an),(k+1)*24)) >=1)
    #jachere
    for p in range(Data.nbparcelle):
        for k in range (0,n):
            model.add_constr(xsum(z[p][Data.nblegumes+1][t] for t in range (k*(Data.an),(k+1)*24)) >=1)
    #une parcelle ne peut pas etre occupé par plus d'un legume
    for p in range(Data.nbparcelle):
        for t in range(Data.horizon):
            model.add_constr(xsum(x[p][l][t] for l in range(Data.nblegumes+2)) <= 1)
    #adjacence
    for p in range(Data.nbparcelle):
        for pprim in Data.voisin[p]:
            for l in range(Data.nblegumes+2):
                for t in range(Data.horizon):
                    model.add_constr(xsum(x[pprim][lprim][t] for lprim in range(Data.nblegumes+2) if Data.family[lprim]==Data.family[l] and Data.lnumber[lprim] != Data.lnumber[l])  <= 1-x[p][l][t] )
    #continuite
    for p in range(Data.nbparcelle):
        for l in range(Data.nblegumes+2):
            for t in range(Data.horizon):
                model.add_constr(xsum(z[p][lprim][tprim] for lprim in range(Data.nblegumes+2) for tprim in range( (t-Data.croissance[lprim]-Data.rest[lprim]+1)%Data.horizon ,t) if Data.family[lprim]==Data.family[l] ) <= 1-z[p][l][t] )
                model.add_constr(xsum(z[p][l][tprim] for tprim in range(t-Data.croissance[l]+1,t+1))  == x[p][l][t] )                        
    return model


def model_solution_bis( Data , n):
    model  = build_model_bis(Data , n)
    status = model.optimize(max_seconds=300)
    if status == OptimizationStatus.OPTIMAL:
        print('optimal solution cost {} found'.format(model.objective_value))
    elif status == OptimizationStatus.FEASIBLE:
        print('sol.cost {} found, best possible: {}'.format(model.objective_value, model.objective_bound))
    elif status == OptimizationStatus.NO_SOLUTION_FOUND:
        print('no feasible solution found, lower bound is: {}'.format(model.objective_bound))
    if status == OptimizationStatus.OPTIMAL or status == OptimizationStatus.FEASIBLE:
        solution=[]
        for p in range(Data.nbparcelle):
            for l in range(Data.nblegumes+2):
                for t in range(Data.horizon):
                    if model.vars[(Data.nblegumes+2)*Data.horizon*p+Data.horizon*l+t].x > 1e-6:
                            solution.append([p,l,t])
    return solution

# %% [markdown]
# ### Programme déterminant le calendrier optimal pour un horizon multiplié par n

# %%
def solution_horizon( datal, datat , n ):
    data = modif_horizon( datal, datat , n )
    solution = model_solution_bis(data,n)
    return solution

# %% [markdown]
# ### Renvoie un graphe représentant le profit optimal par an en fonction du nombre d'années de l'horizon

# %%
def convergence_solution_horizon ( datal , datat , n ):
    V=[]
    for i in range (1, n+1):
        sol = model_solution_bis(modif_horizon(datal,datat,i),i)
        S = solution ( sol , modif_horizon(datal,datat,i))
        V.append(S.profits()/i)
    T=[k for k in range (1,n+1)]
    matplotlib.pyplot.plot(T,V)

# %% [markdown]
# ### On trace le graphe pour 15 ans

# %%
#datat="Expériences/data_terrain_petit.txt"
#datal="Expériences/data_legumes_petit.txt"
#data=Data(datal,datat)

#convergence_solution_horizon( datal, datat, 15)
# Out:
# Cgl0003I 0 fixed, 0 tightened bounds, 2655 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2655 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2177 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1325 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 967 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 537 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 227 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 28 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1944 rows, 2700 columns (2700 integer (2700 of which binary)) and 12777 elements
# Coin3009W Conflict graph built in 0.003 seconds, density: 0.115%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 371 integers unsatisfied sum - 174.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -2.14418e+06 iterations 1751
# Cbc0038I Solution found of -2.14418e+06
# Cbc0038I Rounding solution of -2.7201e+06 is better than previous of -2.14418e+06
#
# Cbc0038I Before mini branch and bound, 2296 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 417 rows 361 columns
# Cbc0038I Mini branch and bound improved solution from -2.7201e+06 to -2.78062e+06 (1.10 seconds)
# Cbc0038I Round again with cutoff of -2.7895e+06
# Cbc0038I Pass   2: suminf.   89.31667 (186) obj. -2.7895e+06 iterations 1117
# Cbc0038I Pass   3: suminf.   57.31333 (115) obj. -2.7895e+06 iterations 406
# Cbc0038I Pass   4: suminf.   47.34815 (95) obj. -2.7895e+06 iterations 287
# Cbc0038I Pass   5: suminf.   45.51481 (92) obj. -2.7895e+06 iterations 197
# Cbc0038I Pass   6: suminf.   42.49630 (85) obj. -2.7895e+06 iterations 191
# Cbc0038I Pass   7: suminf.   38.66296 (78) obj. -2.7895e+06 iterations 132
# Cbc0038I Pass   8: suminf.   38.66296 (78) obj. -2.7895e+06 iterations 76
# Cbc0038I Pass   9: suminf.   36.85887 (78) obj. -2.7895e+06 iterations 72
# Cbc0038I Pass  10: suminf.   36.85887 (78) obj. -2.7895e+06 iterations 60
# Cbc0038I Pass  11: suminf.   36.85887 (78) obj. -2.7895e+06 iterations 31
# Cbc0038I Pass  12: suminf.   36.85887 (78) obj. -2.7895e+06 iterations 29
# Cbc0038I Pass  13: suminf.   36.85887 (78) obj. -2.7895e+06 iterations 16
# Cbc0038I Pass  14: suminf.   39.07436 (85) obj. -2.7895e+06 iterations 540
# Cbc0038I Pass  15: suminf.   29.97766 (60) obj. -2.7895e+06 iterations 394
# Cbc0038I Pass  16: suminf.   28.97766 (58) obj. -2.7895e+06 iterations 95
# Cbc0038I Pass  17: suminf.   28.97766 (58) obj. -2.7895e+06 iterations 27
# Cbc0038I Pass  18: suminf.   28.97766 (58) obj. -2.7895e+06 iterations 9
# Cbc0038I Pass  19: suminf.   28.97766 (58) obj. -2.7895e+06 iterations 83
# Cbc0038I Pass  20: suminf.   28.97766 (58) obj. -2.7895e+06 iterations 87
# Cbc0038I Pass  21: suminf.   27.85556 (56) obj. -2.7895e+06 iterations 75
# Cbc0038I Pass  22: suminf.   24.05926 (49) obj. -2.7895e+06 iterations 129
# Cbc0038I Pass  23: suminf.   23.89841 (48) obj. -2.7895e+06 iterations 236
# Cbc0038I Pass  24: suminf.   23.20565 (49) obj. -2.7895e+06 iterations 242
# Cbc0038I Pass  25: suminf.   23.20565 (49) obj. -2.7895e+06 iterations 77
# Cbc0038I Pass  26: suminf.   23.20565 (49) obj. -2.7895e+06 iterations 61
# Cbc0038I Pass  27: suminf.   23.20565 (49) obj. -2.7895e+06 iterations 37
# Cbc0038I Pass  28: suminf.   23.20565 (49) obj. -2.7895e+06 iterations 51
# Cbc0038I Pass  29: suminf.   23.20565 (49) obj. -2.7895e+06 iterations 41
# Cbc0038I Pass  30: suminf.   23.20565 (49) obj. -2.7895e+06 iterations 20
# Cbc0038I Pass  31: suminf.   22.16250 (45) obj. -2.7895e+06 iterations 64
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2215 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 516 rows 453 columns
# Cbc0038I Mini branch and bound did not improve solution (1.78 seconds)
# Cbc0038I After 1.78 seconds - Feasibility pump exiting with objective of -2.78062e+06 - took 0.92 seconds
# Cbc0012I Integer solution of -2780625 found by feasibility pump after 0 iterations and 0 nodes (1.78 seconds)
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 365 rows 322 columns
# Cbc0012I Integer solution of -2784525 found by RINS after 0 iterations and 0 nodes (2.04 seconds)
# Cbc0012I Integer solution of -2814075 found by DiveCoefficient after 3705 iterations and 0 nodes (9.96 seconds)
# Cbc0031I 80 added rows had average density of 172.4875
# Cbc0013I At root node, 80 cuts changed objective from -2868750 to -2834089.7 in 27 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (72 active)  in 0.168 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 702 row cuts average 483.9 elements, 0 column cuts (0 active)  in 3.540 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.166 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.356 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.836 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 1 row cuts average 135.0 elements, 0 column cuts (0 active)  in 0.084 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 322 row cuts average 211.9 elements, 0 column cuts (0 active)  in 1.317 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -2814075 best solution, best possible -2834089.7 (10.14 seconds)
# Cbc0012I Integer solution of -2827275 found by DiveCoefficient after 3808 iterations and 2 nodes (10.55 seconds)
# Cbc0010I After 3 nodes, 4 on tree, -2827275 best solution, best possible -2834089.7 (11.02 seconds)
# Cbc0012I Integer solution of -2828475 found by DiveCoefficient after 3844 iterations and 4 nodes (11.35 seconds)
# Cbc0010I After 5 nodes, 6 on tree, -2828475 best solution, best possible -2834089.7 (11.73 seconds)
# Cbc0012I Integer solution of -2831475 found by DiveCoefficient after 3899 iterations and 6 nodes (11.91 seconds)
# Cbc0010I After 11 nodes, 11 on tree, -2831475 best solution, best possible -2834089.7 (12.47 seconds)
# Cbc0010I After 31 nodes, 25 on tree, -2831475 best solution, best possible -2834089.7 (13.19 seconds)
# Cbc0004I Integer solution of -2833275 found after 5045 iterations and 35 nodes (13.30 seconds)
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 910 rows 752 columns
# Cbc0010I After 43 nodes, 19 on tree, -2833275 best solution, best possible -2834089.7 (13.91 seconds)
# Cbc0038I Full problem 2024 rows 2700 columns, reduced to 1944 rows 2356 columns - too large
# Cbc0004I Integer solution of -2833500 found after 6217 iterations and 62 nodes (14.30 seconds)
# Cbc0010I After 76 nodes, 4 on tree, -2833500 best solution, best possible -2834089.7 (14.86 seconds)
# Cbc0010I After 89 nodes, 3 on tree, -2833500 best solution, best possible -2834089.7 (15.72 seconds)
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 1059 rows 859 columns
# Cbc0010I After 93 nodes, 7 on tree, -2833500 best solution, best possible -2834089.7 (16.62 seconds)
# Cbc0010I After 101 nodes, 9 on tree, -2833500 best solution, best possible -2834089.7 (17.35 seconds)
# Cbc0010I After 120 nodes, 17 on tree, -2833500 best solution, best possible -2834089.7 (18.13 seconds)
# Cbc0010I After 144 nodes, 24 on tree, -2833500 best solution, best possible -2834089.7 (18.85 seconds)
# Cbc0010I After 175 nodes, 28 on tree, -2833500 best solution, best possible -2834089.7 (19.57 seconds)
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 949 rows 769 columns
# Cbc0010I After 200 nodes, 32 on tree, -2833500 best solution, best possible -2834089.7 (20.34 seconds)
# Cbc0010I After 232 nodes, 34 on tree, -2833500 best solution, best possible -2834089.7 (21.05 seconds)
# Cbc0010I After 266 nodes, 39 on tree, -2833500 best solution, best possible -2834089.7 (21.77 seconds)
# Cbc0010I After 296 nodes, 37 on tree, -2833500 best solution, best possible -2834089.7 (22.47 seconds)
# Cbc0010I After 325 nodes, 38 on tree, -2833500 best solution, best possible -2834089.7 (23.20 seconds)
# Cbc0010I After 365 nodes, 34 on tree, -2833500 best solution, best possible -2834089.7 (23.92 seconds)
# Cbc0010I After 398 nodes, 34 on tree, -2833500 best solution, best possible -2834089.7 (24.62 seconds)
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 797 rows 653 columns
# Cbc0010I After 430 nodes, 34 on tree, -2833500 best solution, best possible -2834089.7 (25.34 seconds)
# Cbc0010I After 461 nodes, 37 on tree, -2833500 best solution, best possible -2834089.7 (26.06 seconds)
# Cbc0010I After 503 nodes, 29 on tree, -2833500 best solution, best possible -2834089.7 (26.78 seconds)
# Cbc0010I After 545 nodes, 26 on tree, -2833500 best solution, best possible -2834089.7 (27.49 seconds)
# Cbc0010I After 589 nodes, 18 on tree, -2833500 best solution, best possible -2834089.7 (28.21 seconds)
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 1070 rows 863 columns
# Cbc0010I After 620 nodes, 18 on tree, -2833500 best solution, best possible -2834089.7 (28.91 seconds)
# Cbc0010I After 673 nodes, 8 on tree, -2833500 best solution, best possible -2834089.7 (29.62 seconds)
# Cbc0010I After 690 nodes, 6 on tree, -2833500 best solution, best possible -2834089.7 (30.32 seconds)
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 936 rows 765 columns
# Cbc0010I After 700 nodes, 4 on tree, -2833500 best solution, best possible -2834089.7 (31.29 seconds)
# Cbc0010I After 716 nodes, 7 on tree, -2833500 best solution, best possible -2834089.7 (32.00 seconds)
# Cbc0010I After 733 nodes, 4 on tree, -2833500 best solution, best possible -2834089.7 (32.70 seconds)
# Cbc0010I After 743 nodes, 1 on tree, -2833500 best solution, best possible -2834069.2 (33.53 seconds)
# Cbc0010I After 746 nodes, 4 on tree, -2833500 best solution, best possible -2834069.2 (34.48 seconds)
# Cbc0010I After 754 nodes, 7 on tree, -2833500 best solution, best possible -2834069.2 (35.24 seconds)
# Cbc0010I After 764 nodes, 6 on tree, -2833500 best solution, best possible -2834069.2 (36.03 seconds)
# Cbc0010I After 785 nodes, 3 on tree, -2833500 best solution, best possible -2834069.2 (36.77 seconds)
# Cbc0010I After 789 nodes, 3 on tree, -2833500 best solution, best possible -2834069.2 (37.52 seconds)
# Cbc0010I After 797 nodes, 6 on tree, -2833500 best solution, best possible -2834069.2 (38.43 seconds)
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 1206 rows 968 columns - 40 fixed gives 1043, 831 - ok now
# Cbc0038I Full problem 1944 rows 2700 columns, reduced to 1009 rows 805 columns
# Cbc0010I After 819 nodes, 3 on tree, -2833500 best solution, best possible -2834069.2 (39.28 seconds)
# Cbc0001I Search completed - best objective -2833500, took 31610 iterations and 823 nodes (39.32 seconds)
# Cbc0032I Strong branching done 3388 times (28093 iterations), fathomed 34 nodes and fixed 9 variables
# Cbc0035I Maximum depth 38, 12860 variables fixed on reduced cost
# Total time (CPU seconds):       38.37   (Wallclock seconds):       40.05
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 330 (-948) rows, 270 (-450) columns and 1242 (-1581) elements
# Clp1000I sum of infeasibilities 1.78332e-07 - average 5.40401e-10, 144 fixed columns
# Coin0506I Presolve 150 (-180) rows, 126 (-144) columns and 444 (-798) elements
# Clp0006I 0  Obj 306750 Dual inf 6787.4999 (78)
# Clp0029I End of values pass after 126 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000004 - largest nonzero change 2.7814208e-05 ( 0.0013907104%) - largest zero change 2.9394864e-05
# Clp0000I Optimal - objective value 306750
# Clp0000I Optimal - objective value 306750
# Coin0511I After Postsolve, objective 306750, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 306750 Dual inf 208350 (54)
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.9669814e-05 ( 0.0014834907%) - largest zero change 2.9394864e-05
# Clp0000I Optimal - objective value 306750
# Clp0000I Optimal - objective value 306750
# Clp0000I Optimal - objective value 306750
# Coin0511I After Postsolve, objective 306750, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 306750 - 0 iterations time 0.042, Presolve 0.00, Idiot 0.04
#
# Starting MIP optimization
# optimal solution cost 284250.0 found
# Cgl0003I 0 fixed, 0 tightened bounds, 252 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 252 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 207 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 123 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 94 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 52 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 189 rows, 270 columns (270 integer (270 of which binary)) and 1248 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 1.140%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 33 integers unsatisfied sum - 16.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -224700 iterations 176
# Cbc0038I Solution found of -224700
# Cbc0038I Rounding solution of -267000 is better than previous of -224700
#
# Cbc0038I Before mini branch and bound, 235 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 189 rows 270 columns, reduced to 34 rows 30 columns
# Cbc0038I Mini branch and bound improved solution from -267000 to -276000 (0.09 seconds)
# Cbc0038I Round again with cutoff of -277155
# Cbc0038I Pass   2: suminf.    6.03667 (20) obj. -277155 iterations 85
# Cbc0038I Pass   3: suminf.    4.26111 (9) obj. -277155 iterations 38
# Cbc0038I Pass   4: suminf.    3.26111 (7) obj. -277155 iterations 18
# Cbc0038I Pass   5: suminf.    3.26111 (7) obj. -277155 iterations 12
# Cbc0038I Pass   6: suminf.    3.28500 (7) obj. -277155 iterations 73
# Cbc0038I Pass   7: suminf.    3.28500 (7) obj. -277155 iterations 53
# Cbc0038I Pass   8: suminf.    3.26111 (7) obj. -277155 iterations 15
# Cbc0038I Pass   9: suminf.    3.32000 (7) obj. -277155 iterations 90
# Cbc0038I Pass  10: suminf.    1.93175 (9) obj. -277155 iterations 104
# Cbc0038I Pass  11: suminf.    1.76111 (4) obj. -277155 iterations 87
# Cbc0038I Pass  12: suminf.    1.76111 (4) obj. -277155 iterations 8
# Cbc0038I Pass  13: suminf.    1.76111 (4) obj. -277155 iterations 4
# Cbc0038I Pass  14: suminf.    2.00000 (4) obj. -277800 iterations 69
# Cbc0038I Pass  15: suminf.    1.93175 (9) obj. -277155 iterations 27
# Cbc0038I Pass  16: suminf.    1.76111 (4) obj. -277155 iterations 76
# Cbc0038I Pass  17: suminf.    1.76111 (4) obj. -277155 iterations 7
# Cbc0038I Pass  18: suminf.    1.76111 (4) obj. -277155 iterations 4
# Cbc0038I Pass  19: suminf.    2.00000 (4) obj. -277800 iterations 64
# Cbc0038I Pass  20: suminf.    1.93175 (9) obj. -277155 iterations 25
# Cbc0038I Pass  21: suminf.    1.76111 (4) obj. -277155 iterations 78
# Cbc0038I Pass  22: suminf.    1.76111 (4) obj. -277155 iterations 7
# Cbc0038I Pass  23: suminf.    1.76111 (4) obj. -277155 iterations 13
# Cbc0038I Pass  24: suminf.    1.76111 (4) obj. -277155 iterations 15
# Cbc0038I Pass  25: suminf.    1.76111 (4) obj. -277155 iterations 2
# Cbc0038I Pass  26: suminf.    2.00000 (4) obj. -277800 iterations 71
# Cbc0038I Pass  27: suminf.    1.93175 (9) obj. -277155 iterations 29
# Cbc0038I Pass  28: suminf.    1.76111 (4) obj. -277155 iterations 88
# Cbc0038I Pass  29: suminf.    4.84667 (16) obj. -277155 iterations 92
# Cbc0038I Pass  30: suminf.    2.90000 (6) obj. -277155 iterations 39
# Cbc0038I Pass  31: suminf.    2.11290 (5) obj. -277155 iterations 9
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 197 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 189 rows 270 columns, reduced to 82 rows 71 columns
# Cbc0038I Mini branch and bound improved solution from -276000 to -280275 (0.13 seconds)
# Cbc0038I Round again with cutoff of -281655
# Cbc0038I Pass  31: suminf.   11.50000 (27) obj. -281655 iterations 20
# Cbc0038I Pass  32: suminf.    5.40000 (11) obj. -281655 iterations 43
# Cbc0038I Pass  33: suminf.    4.70000 (10) obj. -281655 iterations 47
# Cbc0038I Pass  34: suminf.    4.70000 (10) obj. -281655 iterations 23
# Cbc0038I Pass  35: suminf.    4.70000 (10) obj. -281655 iterations 27
# Cbc0038I Pass  36: suminf.    3.70000 (8) obj. -281655 iterations 20
# Cbc0038I Pass  37: suminf.    3.70000 (8) obj. -281655 iterations 3
# Cbc0038I Pass  38: suminf.    3.76000 (8) obj. -281655 iterations 46
# Cbc0038I Pass  39: suminf.    3.70000 (8) obj. -281655 iterations 24
# Cbc0038I Pass  40: suminf.    3.70000 (8) obj. -281655 iterations 21
# Cbc0038I Pass  41: suminf.    3.70000 (8) obj. -281655 iterations 17
# Cbc0038I Pass  42: suminf.    3.70000 (8) obj. -281655 iterations 4
# Cbc0038I Pass  43: suminf.    7.80000 (17) obj. -281655 iterations 92
# Cbc0038I Pass  44: suminf.    4.64255 (10) obj. -281655 iterations 73
# Cbc0038I Pass  45: suminf.    3.76000 (8) obj. -281655 iterations 74
# Cbc0038I Pass  46: suminf.    3.70000 (8) obj. -281655 iterations 28
# Cbc0038I Pass  47: suminf.    3.70000 (8) obj. -281655 iterations 23
# Cbc0038I Pass  48: suminf.    3.70000 (8) obj. -281655 iterations 14
# Cbc0038I Pass  49: suminf.    3.73333 (8) obj. -281655 iterations 53
# Cbc0038I Pass  50: suminf.    3.70000 (8) obj. -281655 iterations 25
# Cbc0038I Pass  51: suminf.    3.70000 (8) obj. -281655 iterations 6
# Cbc0038I Pass  52: suminf.    3.58621 (8) obj. -281655 iterations 20
# Cbc0038I Pass  53: suminf.    3.58621 (8) obj. -281655 iterations 14
# Cbc0038I Pass  54: suminf.    5.20909 (17) obj. -281655 iterations 75
# Cbc0038I Pass  55: suminf.    3.81538 (10) obj. -281655 iterations 101
# Cbc0038I Pass  56: suminf.    4.70000 (10) obj. -281655 iterations 102
# Cbc0038I Pass  57: suminf.    3.70000 (8) obj. -281655 iterations 24
# Cbc0038I Pass  58: suminf.    3.70000 (8) obj. -281655 iterations 22
# Cbc0038I Pass  59: suminf.    3.70000 (8) obj. -281655 iterations 24
# Cbc0038I Pass  60: suminf.    3.70000 (8) obj. -281655 iterations 16
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 209 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 189 rows 270 columns, reduced to 62 rows 59 columns
# Cbc0038I Mini branch and bound did not improve solution (0.18 seconds)
# Cbc0038I After 0.18 seconds - Feasibility pump exiting with objective of -280275 - took 0.11 seconds
# Cbc0012I Integer solution of -280275 found by feasibility pump after 0 iterations and 0 nodes (0.18 seconds)
# Cbc0012I Integer solution of -280650 found by DiveCoefficient after 0 iterations and 0 nodes (0.19 seconds)
# Cbc0038I Full problem 189 rows 270 columns, reduced to 42 rows 40 columns
# Cbc0012I Integer solution of -280875 found by RINS after 0 iterations and 0 nodes (0.20 seconds)
# Cbc0012I Integer solution of -284250 found by DiveCoefficient after 33 iterations and 0 nodes (0.22 seconds)
# Cbc0031I 5 added rows had average density of 30.8
# Cbc0013I At root node, 5 cuts changed objective from -286875 to -284250 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 32.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 5 row cuts average 30.8 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -284250, took 33 iterations and 0 nodes (0.22 seconds)
# Cbc0035I Maximum depth 0, 12 variables fixed on reduced cost
# Total time (CPU seconds):       0.24   (Wallclock seconds):       0.25
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 675 (-1881) rows, 540 (-900) columns and 2520 (-3159) elements
# Clp1000I sum of infeasibilities 3.75795e-07 - average 5.56734e-10, 288 fixed columns
# Coin0506I Presolve 300 (-375) rows, 252 (-288) columns and 888 (-1632) elements
# Clp0006I 0  Obj 613499.99 Dual inf 13575 (156)
# Clp0029I End of values pass after 252 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000002 - largest nonzero change 2.9283559e-05 ( 0.0014641779%) - largest zero change 2.7270429e-05
# Clp0000I Optimal - objective value 613500
# Clp0000I Optimal - objective value 613500
# Coin0511I After Postsolve, objective 613500, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 613500 Dual inf 351412.5 (101)
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.9283558e-05 ( 0.0014641779%) - largest zero change 2.9019187e-05
# Clp0000I Optimal - objective value 613500
# Clp0000I Optimal - objective value 613500
# Clp0000I Optimal - objective value 613500
# Coin0511I After Postsolve, objective 613500, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 613500 - 0 iterations time 0.082, Presolve 0.00, Idiot 0.08
#
# Starting MIP optimization
# optimal solution cost 566250.0 found
# Cgl0003I 0 fixed, 0 tightened bounds, 519 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 519 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 426 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 256 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 193 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 105 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 48 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0004I processed model has 384 rows, 540 columns (540 integer (540 of which binary)) and 2529 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 0.571%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 66 integers unsatisfied sum - 33
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -432000 iterations 343
# Cbc0038I Solution found of -432000
# Cbc0038I Rounding solution of -542025 is better than previous of -432000
#
# Cbc0038I Before mini branch and bound, 470 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 384 rows 540 columns, reduced to 68 rows 60 columns
# Cbc0038I Mini branch and bound improved solution from -542025 to -552000 (0.20 seconds)
# Cbc0038I Round again with cutoff of -554242
# Cbc0038I Pass   2: suminf.   19.08056 (39) obj. -554242 iterations 192
# Cbc0038I Pass   3: suminf.   11.57037 (24) obj. -554242 iterations 62
# Cbc0038I Pass   4: suminf.   10.57037 (22) obj. -554242 iterations 15
# Cbc0038I Pass   5: suminf.   10.57037 (22) obj. -554242 iterations 18
# Cbc0038I Pass   6: suminf.   10.57037 (22) obj. -554242 iterations 48
# Cbc0038I Pass   7: suminf.    9.57037 (20) obj. -554242 iterations 34
# Cbc0038I Pass   8: suminf.    7.73704 (19) obj. -554242 iterations 37
# Cbc0038I Pass   9: suminf.    6.77812 (14) obj. -554242 iterations 83
# Cbc0038I Pass  10: suminf.    6.77812 (14) obj. -554242 iterations 24
# Cbc0038I Pass  11: suminf.    6.38519 (13) obj. -554242 iterations 33
# Cbc0038I Pass  12: suminf.    6.38519 (13) obj. -554242 iterations 20
# Cbc0038I Pass  13: suminf.    3.68333 (8) obj. -554242 iterations 29
# Cbc0038I Pass  14: suminf.    3.68333 (8) obj. -554242 iterations 1
# Cbc0038I Pass  15: suminf.    3.71852 (8) obj. -554242 iterations 40
# Cbc0038I Pass  16: suminf.    3.17672 (8) obj. -554242 iterations 33
# Cbc0038I Pass  17: suminf.    3.17672 (8) obj. -554242 iterations 11
# Cbc0038I Pass  18: suminf.    3.47250 (7) obj. -554242 iterations 112
# Cbc0038I Pass  19: suminf.    3.41389 (7) obj. -554242 iterations 14
# Cbc0038I Pass  20: suminf.    3.41389 (7) obj. -554242 iterations 30
# Cbc0038I Pass  21: suminf.    3.41389 (7) obj. -554242 iterations 28
# Cbc0038I Pass  22: suminf.    3.41389 (7) obj. -554242 iterations 15
# Cbc0038I Pass  23: suminf.    8.69083 (23) obj. -554242 iterations 156
# Cbc0038I Pass  24: suminf.    3.83611 (8) obj. -554242 iterations 123
# Cbc0038I Pass  25: suminf.    3.16389 (7) obj. -554242 iterations 84
# Cbc0038I Pass  26: suminf.    3.16389 (7) obj. -554242 iterations 5
# Cbc0038I Pass  27: suminf.    3.19750 (7) obj. -554242 iterations 46
# Cbc0038I Pass  28: suminf.    3.16389 (7) obj. -554242 iterations 16
# Cbc0038I Pass  29: suminf.    3.16389 (7) obj. -554242 iterations 6
# Cbc0038I Pass  30: suminf.    3.16389 (7) obj. -554242 iterations 10
# Cbc0038I Pass  31: suminf.    3.19750 (7) obj. -554242 iterations 54
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 450 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 384 rows 540 columns, reduced to 96 rows 81 columns
# Cbc0038I Mini branch and bound improved solution from -552000 to -561600 (0.30 seconds)
# Cbc0038I Round again with cutoff of -564090
# Cbc0038I Pass  31: suminf.   19.45185 (40) obj. -564090 iterations 29
# Cbc0038I Pass  32: suminf.   14.52593 (30) obj. -564090 iterations 68
# Cbc0038I Pass  33: suminf.   13.47407 (30) obj. -564090 iterations 67
# Cbc0038I Pass  34: suminf.   11.52593 (24) obj. -564090 iterations 57
# Cbc0038I Pass  35: suminf.   11.52593 (24) obj. -564090 iterations 51
# Cbc0038I Pass  36: suminf.   11.52593 (24) obj. -564090 iterations 8
# Cbc0038I Pass  37: suminf.   11.52593 (24) obj. -564090 iterations 18
# Cbc0038I Pass  38: suminf.   11.52593 (24) obj. -564090 iterations 10
# Cbc0038I Pass  39: suminf.   11.52593 (24) obj. -564090 iterations 3
# Cbc0038I Pass  40: suminf.   11.52593 (24) obj. -564090 iterations 12
# Cbc0038I Pass  41: suminf.   11.52593 (24) obj. -564090 iterations 45
# Cbc0038I Pass  42: suminf.   10.32222 (21) obj. -564090 iterations 61
# Cbc0038I Pass  43: suminf.    8.53226 (21) obj. -564090 iterations 44
# Cbc0038I Pass  44: suminf.    7.80242 (17) obj. -564090 iterations 33
# Cbc0038I Pass  45: suminf.    7.80242 (17) obj. -564090 iterations 11
# Cbc0038I Pass  46: suminf.    7.88125 (16) obj. -564090 iterations 212
# Cbc0038I Pass  47: suminf.    7.73707 (18) obj. -564090 iterations 71
# Cbc0038I Pass  48: suminf.    7.73707 (18) obj. -564090 iterations 57
# Cbc0038I Pass  49: suminf.    7.73707 (18) obj. -564090 iterations 26
# Cbc0038I Pass  50: suminf.    7.73707 (18) obj. -564090 iterations 19
# Cbc0038I Pass  51: suminf.    7.87333 (16) obj. -564090 iterations 101
# Cbc0038I Pass  52: suminf.    7.87333 (16) obj. -564090 iterations 48
# Cbc0038I Pass  53: suminf.    7.77917 (18) obj. -564090 iterations 83
# Cbc0038I Pass  54: suminf.    7.77917 (18) obj. -564090 iterations 19
# Cbc0038I Pass  55: suminf.    6.09167 (13) obj. -564090 iterations 14
# Cbc0038I Pass  56: suminf.    6.09167 (13) obj. -564090 iterations 6
# Cbc0038I Pass  57: suminf.    6.17222 (13) obj. -564090 iterations 106
# Cbc0038I Pass  58: suminf.    6.13125 (13) obj. -564090 iterations 36
# Cbc0038I Pass  59: suminf.    5.99138 (13) obj. -564090 iterations 64
# Cbc0038I Pass  60: suminf.    5.99138 (13) obj. -564090 iterations 9
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 453 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 384 rows 540 columns, reduced to 92 rows 78 columns
# Cbc0038I Mini branch and bound did not improve solution (0.40 seconds)
# Cbc0038I After 0.40 seconds - Feasibility pump exiting with objective of -561600 - took 0.24 seconds
# Cbc0012I Integer solution of -561600 found by feasibility pump after 0 iterations and 0 nodes (0.40 seconds)
# Cbc0038I Full problem 384 rows 540 columns, reduced to 72 rows 62 columns
# Cbc0031I 17 added rows had average density of 83.117647
# Cbc0013I At root node, 17 cuts changed objective from -573750 to -566775 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 84 row cuts average 107.9 elements, 0 column cuts (0 active)  in 0.021 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 1 row cuts average 39.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 60 row cuts average 103.0 elements, 0 column cuts (0 active)  in 0.053 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -561600 best solution, best possible -566775 (0.70 seconds)
# Cbc0012I Integer solution of -562950 found by DiveCoefficient after 502 iterations and 1 nodes (0.73 seconds)
# Cbc0016I Integer solution of -566025 found by strong branching after 942 iterations and 15 nodes (1.13 seconds)
# Cbc0004I Integer solution of -566250 found after 1024 iterations and 19 nodes (1.16 seconds)
# Cbc0001I Search completed - best objective -566250, took 2033 iterations and 43 nodes (1.35 seconds)
# Cbc0032I Strong branching done 736 times (9779 iterations), fathomed 7 nodes and fixed 25 variables
# Cbc0035I Maximum depth 13, 606 variables fixed on reduced cost
# Total time (CPU seconds):       1.37   (Wallclock seconds):       1.42
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
# Coin0506I Presolve 1020 (-2814) rows, 810 (-1350) columns and 3798 (-4737) elements
# Clp1000I sum of infeasibilities 4.97671e-07 - average 4.87912e-10, 432 fixed columns
# Coin0506I Presolve 450 (-570) rows, 378 (-432) columns and 1332 (-2466) elements
# Clp0006I 0  Obj 920249.99 Dual inf 20362.5 (234)
# Clp0029I End of values pass after 378 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.8913165e-05 ( 0.0014456583%) - largest zero change 2.9278563e-05
# Clp0000I Optimal - objective value 920250
# Clp0000I Optimal - objective value 920250
# Coin0511I After Postsolve, objective 920250, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 920250 Dual inf 439762.5 (150)
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.9936919e-05 ( 0.0014968459%) - largest zero change 2.8656153e-05
# Clp0000I Optimal - objective value 920250
# Clp0000I Optimal - objective value 920250
# Clp0000I Optimal - objective value 920250
# Coin0511I After Postsolve, objective 920250, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 920250 - 0 iterations time 0.132, Presolve 0.01, Idiot 0.12
#
# Starting MIP optimization
# optimal solution cost 850500.0 found
# Cgl0003I 0 fixed, 0 tightened bounds, 786 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 786 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 645 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 387 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 291 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 159 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 70 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0004I processed model has 579 rows, 810 columns (810 integer (810 of which binary)) and 3810 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 0.381%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 109 integers unsatisfied sum - 50.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -658800 iterations 508
# Cbc0038I Solution found of -658800
# Cbc0038I Rounding solution of -824700 is better than previous of -658800
#
# Cbc0038I Before mini branch and bound, 691 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 579 rows 810 columns, reduced to 119 rows 105 columns
# Cbc0038I Mini branch and bound improved solution from -824700 to -836775 (0.32 seconds)
# Cbc0038I Round again with cutoff of -839227
# Cbc0038I Pass   2: suminf.   26.26944 (53) obj. -839227 iterations 311
# Cbc0038I Pass   3: suminf.   21.15667 (45) obj. -839227 iterations 97
# Cbc0038I Pass   4: suminf.   14.45185 (29) obj. -839227 iterations 116
# Cbc0038I Pass   5: suminf.   13.45185 (27) obj. -839227 iterations 86
# Cbc0038I Pass   6: suminf.   13.45185 (27) obj. -839227 iterations 58
# Cbc0038I Pass   7: suminf.   13.45185 (27) obj. -839227 iterations 46
# Cbc0038I Pass   8: suminf.   13.45185 (27) obj. -839227 iterations 29
# Cbc0038I Pass   9: suminf.   13.45185 (27) obj. -839227 iterations 5
# Cbc0038I Pass  10: suminf.   13.45185 (27) obj. -839227 iterations 152
# Cbc0038I Pass  11: suminf.   13.45185 (27) obj. -839227 iterations 72
# Cbc0038I Pass  12: suminf.   13.45185 (27) obj. -839227 iterations 36
# Cbc0038I Pass  13: suminf.   12.30417 (25) obj. -839227 iterations 52
# Cbc0038I Pass  14: suminf.   11.72963 (24) obj. -839227 iterations 64
# Cbc0038I Pass  15: suminf.   10.00833 (21) obj. -839227 iterations 70
# Cbc0038I Pass  16: suminf.   10.00833 (21) obj. -839227 iterations 24
# Cbc0038I Pass  17: suminf.   10.00833 (21) obj. -839227 iterations 52
# Cbc0038I Pass  18: suminf.    9.95873 (21) obj. -839227 iterations 110
# Cbc0038I Pass  19: suminf.    9.95873 (21) obj. -839227 iterations 25
# Cbc0038I Pass  20: suminf.    9.95873 (21) obj. -839227 iterations 72
# Cbc0038I Pass  21: suminf.   15.78095 (38) obj. -839227 iterations 213
# Cbc0038I Pass  22: suminf.   12.72963 (26) obj. -839227 iterations 164
# Cbc0038I Pass  23: suminf.   10.94583 (22) obj. -839227 iterations 98
# Cbc0038I Pass  24: suminf.   10.94583 (22) obj. -839227 iterations 41
# Cbc0038I Pass  25: suminf.   10.94583 (22) obj. -839227 iterations 8
# Cbc0038I Pass  26: suminf.   11.56000 (26) obj. -839227 iterations 248
# Cbc0038I Pass  27: suminf.    9.69375 (20) obj. -839227 iterations 196
# Cbc0038I Pass  28: suminf.    7.69375 (16) obj. -839227 iterations 27
# Cbc0038I Pass  29: suminf.    7.69375 (16) obj. -839227 iterations 4
# Cbc0038I Pass  30: suminf.   16.13793 (39) obj. -839227 iterations 280
# Cbc0038I Pass  31: suminf.   13.96167 (30) obj. -839227 iterations 165
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 617 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 579 rows 810 columns, reduced to 194 rows 178 columns
# Cbc0038I Mini branch and bound improved solution from -836775 to -843300 (0.56 seconds)
# Cbc0038I Round again with cutoff of -846825
# Cbc0038I Pass  31: suminf.   28.75926 (58) obj. -846825 iterations 60
# Cbc0038I Pass  32: suminf.   19.37037 (39) obj. -846825 iterations 133
# Cbc0038I Pass  33: suminf.   18.37037 (37) obj. -846825 iterations 81
# Cbc0038I Pass  34: suminf.   18.37037 (37) obj. -846825 iterations 47
# Cbc0038I Pass  35: suminf.   14.02083 (29) obj. -846825 iterations 88
# Cbc0038I Pass  36: suminf.   12.39583 (25) obj. -846825 iterations 40
# Cbc0038I Pass  37: suminf.   12.39583 (25) obj. -846825 iterations 20
# Cbc0038I Pass  38: suminf.   12.39583 (25) obj. -846825 iterations 78
# Cbc0038I Pass  39: suminf.   10.77778 (26) obj. -846825 iterations 78
# Cbc0038I Pass  40: suminf.   10.77778 (26) obj. -846825 iterations 37
# Cbc0038I Pass  41: suminf.   10.77778 (26) obj. -846825 iterations 53
# Cbc0038I Pass  42: suminf.   10.77778 (26) obj. -846825 iterations 33
# Cbc0038I Pass  43: suminf.   10.77778 (26) obj. -846825 iterations 25
# Cbc0038I Pass  44: suminf.   10.77778 (26) obj. -846825 iterations 34
# Cbc0038I Pass  45: suminf.   10.77778 (26) obj. -846825 iterations 42
# Cbc0038I Pass  46: suminf.   14.80556 (35) obj. -846825 iterations 194
# Cbc0038I Pass  47: suminf.    7.70000 (20) obj. -846825 iterations 160
# Cbc0038I Pass  48: suminf.    7.70000 (20) obj. -846825 iterations 5
# Cbc0038I Pass  49: suminf.    8.55000 (18) obj. -846825 iterations 178
# Cbc0038I Pass  50: suminf.    6.44444 (13) obj. -846825 iterations 45
# Cbc0038I Pass  51: suminf.    6.44444 (13) obj. -846825 iterations 37
# Cbc0038I Pass  52: suminf.    6.44444 (13) obj. -846825 iterations 50
# Cbc0038I Pass  53: suminf.    6.44444 (13) obj. -846825 iterations 86
# Cbc0038I Pass  54: suminf.    6.44444 (13) obj. -846825 iterations 39
# Cbc0038I Pass  55: suminf.    6.44444 (13) obj. -846825 iterations 21
# Cbc0038I Pass  56: suminf.    6.45000 (13) obj. -846825 iterations 170
# Cbc0038I Pass  57: suminf.    6.22414 (14) obj. -846825 iterations 188
# Cbc0038I Pass  58: suminf.    6.22414 (14) obj. -846825 iterations 34
# Cbc0038I Pass  59: suminf.    6.50000 (13) obj. -846825 iterations 125
# Cbc0038I Pass  60: suminf.    6.44444 (13) obj. -846825 iterations 53
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 652 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 579 rows 810 columns, reduced to 167 rows 147 columns
# Cbc0038I Mini branch and bound did not improve solution (0.76 seconds)
# Cbc0038I After 0.76 seconds - Feasibility pump exiting with objective of -843300 - took 0.52 seconds
# Cbc0012I Integer solution of -843300 found by feasibility pump after 0 iterations and 0 nodes (0.76 seconds)
# Cbc0038I Full problem 579 rows 810 columns, reduced to 119 rows 101 columns
# Cbc0012I Integer solution of -843600 found by RINS after 0 iterations and 0 nodes (0.81 seconds)
# Cbc0012I Integer solution of -850500 found by DiveCoefficient after 241 iterations and 0 nodes (0.95 seconds)
# Cbc0031I 24 added rows had average density of 68.125
# Cbc0013I At root node, 24 cuts changed objective from -860625 to -850500 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 82 row cuts average 95.6 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 89 row cuts average 99.1 elements, 0 column cuts (0 active)  in 0.053 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -850500, took 241 iterations and 0 nodes (0.95 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       1.01   (Wallclock seconds):       1.04
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1365 (-3747) rows, 1080 (-1800) columns and 5076 (-6315) elements
# Clp1000I sum of infeasibilities 6.77389e-07 - average 4.96256e-10, 576 fixed columns
# Coin0506I Presolve 600 (-765) rows, 504 (-576) columns and 1776 (-3300) elements
# Clp0006I 0  Obj 1227000 Dual inf 27150 (312)
# Clp0029I End of values pass after 504 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.9193569e-05 ( 0.0014596785%) - largest zero change 2.9669812e-05
# Clp0000I Optimal - objective value 1227000
# Clp0000I Optimal - objective value 1227000
# Coin0511I After Postsolve, objective 1227000, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 1227000 Dual inf 648337.5 (195)
# Clp0014I Perturbing problem by 0.001% of 1 - largest nonzero change 2.9605685e-05 ( 0.0014802843%) - largest zero change 2.9394864e-05
# Clp0000I Optimal - objective value 1227000
# Clp0000I Optimal - objective value 1227000
# Clp0000I Optimal - objective value 1227000
# Coin0511I After Postsolve, objective 1227000, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 1227000 - 0 iterations time 0.172, Presolve 0.01, Idiot 0.16
#
# Starting MIP optimization
# optimal solution cost 1134000.0 found
# Cgl0003I 0 fixed, 0 tightened bounds, 1053 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1053 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 863 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 524 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 388 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 212 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 96 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 11 strengthened rows, 0 substitutions
# Cgl0004I processed model has 774 rows, 1080 columns (1080 integer (1080 of which binary)) and 5091 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 0.286%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 172 integers unsatisfied sum - 78.3333
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -818850 iterations 682
# Cbc0038I Solution found of -818850
# Cbc0038I Rounding solution of -1.0641e+06 is better than previous of -818850
#
# Cbc0038I Before mini branch and bound, 893 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 774 rows 1080 columns, reduced to 194 rows 170 columns
# Cbc0038I Mini branch and bound improved solution from -1.0641e+06 to -1.1076e+06 (0.43 seconds)
# Cbc0038I Round again with cutoff of -1.11166e+06
# Cbc0038I Pass   2: suminf.   32.43077 (67) obj. -1.11166e+06 iterations 417
# Cbc0038I Pass   3: suminf.   21.98519 (44) obj. -1.11166e+06 iterations 188
# Cbc0038I Pass   4: suminf.   20.98519 (42) obj. -1.11166e+06 iterations 90
# Cbc0038I Pass   5: suminf.   17.15185 (35) obj. -1.11166e+06 iterations 63
# Cbc0038I Pass   6: suminf.   17.15185 (35) obj. -1.11166e+06 iterations 38
# Cbc0038I Pass   7: suminf.   17.15185 (35) obj. -1.11166e+06 iterations 38
# Cbc0038I Pass   8: suminf.   16.83750 (34) obj. -1.11166e+06 iterations 33
# Cbc0038I Pass   9: suminf.   16.83750 (34) obj. -1.11166e+06 iterations 40
# Cbc0038I Pass  10: suminf.   14.28750 (29) obj. -1.11166e+06 iterations 31
# Cbc0038I Pass  11: suminf.   13.74444 (28) obj. -1.11166e+06 iterations 27
# Cbc0038I Pass  12: suminf.   13.74444 (28) obj. -1.11166e+06 iterations 13
# Cbc0038I Pass  13: suminf.   13.74444 (28) obj. -1.11166e+06 iterations 11
# Cbc0038I Pass  14: suminf.   11.24933 (30) obj. -1.11166e+06 iterations 343
# Cbc0038I Pass  15: suminf.    7.95926 (16) obj. -1.11166e+06 iterations 278
# Cbc0038I Pass  16: suminf.    7.04074 (15) obj. -1.11166e+06 iterations 73
# Cbc0038I Pass  17: suminf.    7.04074 (15) obj. -1.11166e+06 iterations 11
# Cbc0038I Pass  18: suminf.    6.04074 (13) obj. -1.11166e+06 iterations 50
# Cbc0038I Pass  19: suminf.    6.04074 (13) obj. -1.11166e+06 iterations 48
# Cbc0038I Pass  20: suminf.    6.04074 (13) obj. -1.11166e+06 iterations 57
# Cbc0038I Pass  21: suminf.    6.04074 (13) obj. -1.11166e+06 iterations 26
# Cbc0038I Pass  22: suminf.    6.19000 (13) obj. -1.11166e+06 iterations 381
# Cbc0038I Pass  23: suminf.    6.04074 (13) obj. -1.11166e+06 iterations 257
# Cbc0038I Pass  24: suminf.    6.04074 (13) obj. -1.11166e+06 iterations 29
# Cbc0038I Pass  25: suminf.    6.04074 (13) obj. -1.11166e+06 iterations 12
# Cbc0038I Pass  26: suminf.    6.04074 (13) obj. -1.11166e+06 iterations 17
# Cbc0038I Pass  27: suminf.    7.59630 (16) obj. -1.11166e+06 iterations 356
# Cbc0038I Pass  28: suminf.    6.59630 (14) obj. -1.11166e+06 iterations 192
# Cbc0038I Pass  29: suminf.    6.59630 (14) obj. -1.11166e+06 iterations 66
# Cbc0038I Pass  30: suminf.    6.59630 (14) obj. -1.11166e+06 iterations 33
# Cbc0038I Pass  31: suminf.    6.59630 (14) obj. -1.11166e+06 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 836 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 774 rows 1080 columns, reduced to 270 rows 233 columns
# Cbc0038I Mini branch and bound improved solution from -1.1076e+06 to -1.1193e+06 (0.72 seconds)
# Cbc0038I Round again with cutoff of -1.125e+06
# Cbc0038I Pass  31: suminf.   35.38889 (71) obj. -1.125e+06 iterations 71
# Cbc0038I Pass  32: suminf.   29.55556 (60) obj. -1.125e+06 iterations 109
# Cbc0038I Pass  33: suminf.   26.43750 (53) obj. -1.125e+06 iterations 141
# Cbc0038I Pass  34: suminf.   20.55172 (46) obj. -1.125e+06 iterations 109
# Cbc0038I Pass  35: suminf.   19.14583 (39) obj. -1.125e+06 iterations 89
# Cbc0038I Pass  36: suminf.   19.14583 (39) obj. -1.125e+06 iterations 88
# Cbc0038I Pass  37: suminf.   17.66667 (39) obj. -1.125e+06 iterations 60
# Cbc0038I Pass  38: suminf.   15.75287 (33) obj. -1.125e+06 iterations 86
# Cbc0038I Pass  39: suminf.   15.75287 (33) obj. -1.125e+06 iterations 55
# Cbc0038I Pass  40: suminf.   15.75287 (33) obj. -1.125e+06 iterations 41
# Cbc0038I Pass  41: suminf.   13.75287 (29) obj. -1.125e+06 iterations 42
# Cbc0038I Pass  42: suminf.   13.75287 (29) obj. -1.125e+06 iterations 30
# Cbc0038I Pass  43: suminf.   13.75287 (29) obj. -1.125e+06 iterations 9
# Cbc0038I Pass  44: suminf.   13.75287 (29) obj. -1.125e+06 iterations 14
# Cbc0038I Pass  45: suminf.   13.75287 (29) obj. -1.125e+06 iterations 35
# Cbc0038I Pass  46: suminf.   12.75287 (27) obj. -1.125e+06 iterations 33
# Cbc0038I Pass  47: suminf.   12.75287 (27) obj. -1.125e+06 iterations 33
# Cbc0038I Pass  48: suminf.   12.75287 (27) obj. -1.125e+06 iterations 18
# Cbc0038I Pass  49: suminf.   16.61111 (36) obj. -1.125e+06 iterations 275
# Cbc0038I Pass  50: suminf.    9.81481 (23) obj. -1.125e+06 iterations 307
# Cbc0038I Pass  51: suminf.    9.23437 (19) obj. -1.125e+06 iterations 86
# Cbc0038I Pass  52: suminf.    9.23437 (19) obj. -1.125e+06 iterations 26
# Cbc0038I Pass  53: suminf.    9.23437 (19) obj. -1.125e+06 iterations 11
# Cbc0038I Pass  54: suminf.    9.23437 (19) obj. -1.125e+06 iterations 10
# Cbc0038I Pass  55: suminf.    9.23437 (19) obj. -1.125e+06 iterations 8
# Cbc0038I Pass  56: suminf.    9.23437 (19) obj. -1.125e+06 iterations 3
# Cbc0038I Pass  57: suminf.   18.80556 (45) obj. -1.125e+06 iterations 351
# Cbc0038I Pass  58: suminf.   16.57407 (36) obj. -1.125e+06 iterations 259
# Cbc0038I Pass  59: suminf.   13.57407 (28) obj. -1.125e+06 iterations 77
# Cbc0038I Pass  60: suminf.   12.04023 (31) obj. -1.125e+06 iterations 132
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 836 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 774 rows 1080 columns, reduced to 250 rows 232 columns
# Cbc0038I Mini branch and bound improved solution from -1.1193e+06 to -1.1238e+06 (0.99 seconds)
# Cbc0038I Round again with cutoff of -1.13175e+06
# Cbc0038I Pass  60: suminf.   37.72222 (76) obj. -1.13175e+06 iterations 18
# ...
# Cbc0010I After 3561 nodes, 205 on tree, -4249500 best solution, best possible -4251537.1 (159.66 seconds)
# Cbc0010I After 3581 nodes, 198 on tree, -4249500 best solution, best possible -4251537.1 (160.37 seconds)
# Cbc0038I Full problem 2919 rows 4050 columns, reduced to 941 rows 762 columns
# Cbc0010I After 3600 nodes, 205 on tree, -4249500 best solution, best possible -4251537.1 (161.36 seconds)
# Cbc0010I After 3624 nodes, 201 on tree, -4249500 best solution, best possible -4251537.1 (162.07 seconds)
# Cbc0010I After 3652 nodes, 202 on tree, -4249500 best solution, best possible -4251537.1 (162.78 seconds)
# Cbc0010I After 3688 nodes, 196 on tree, -4249500 best solution, best possible -4251537.1 (163.48 seconds)
# Cbc0010I After 3718 nodes, 195 on tree, -4249500 best solution, best possible -4251537.1 (164.25 seconds)
# Cbc0010I After 3744 nodes, 191 on tree, -4249500 best solution, best possible -4251537.1 (164.96 seconds)
# Cbc0010I After 3781 nodes, 187 on tree, -4249500 best solution, best possible -4251537.1 (165.68 seconds)
# Cbc0010I After 3801 nodes, 187 on tree, -4249500 best solution, best possible -4251537.1 (166.42 seconds)
# Cbc0010I After 3828 nodes, 185 on tree, -4249500 best solution, best possible -4251537.1 (167.15 seconds)
# Cbc0010I After 3853 nodes, 184 on tree, -4249500 best solution, best possible -4251537.1 (167.87 seconds)
# Cbc0010I After 3877 nodes, 183 on tree, -4249500 best solution, best possible -4251537.1 (168.60 seconds)
# Cbc0010I After 3906 nodes, 179 on tree, -4249500 best solution, best possible -4251537.1 (169.31 seconds)
# Cbc0010I After 3929 nodes, 177 on tree, -4249500 best solution, best possible -4251537.1 (170.02 seconds)
# Cbc0010I After 3951 nodes, 176 on tree, -4249500 best solution, best possible -4251537.1 (170.72 seconds)
# Cbc0010I After 3973 nodes, 179 on tree, -4249500 best solution, best possible -4251537.1 (171.52 seconds)
# Cbc0010I After 3999 nodes, 175 on tree, -4249500 best solution, best possible -4251537.1 (172.22 seconds)
# Cbc0010I After 4021 nodes, 177 on tree, -4249500 best solution, best possible -4251537.1 (172.99 seconds)
# Cbc0010I After 4045 nodes, 176 on tree, -4249500 best solution, best possible -4251537.1 (173.69 seconds)
# Cbc0010I After 4067 nodes, 176 on tree, -4249500 best solution, best possible -4251537.1 (174.39 seconds)
# Cbc0010I After 4092 nodes, 177 on tree, -4249500 best solution, best possible -4251537.1 (175.12 seconds)
# Cbc0010I After 4111 nodes, 174 on tree, -4249500 best solution, best possible -4251537.1 (175.84 seconds)
# Cbc0010I After 4137 nodes, 173 on tree, -4249500 best solution, best possible -4251537.1 (176.65 seconds)
# Cbc0010I After 4161 nodes, 175 on tree, -4249500 best solution, best possible -4251537.1 (177.36 seconds)
# Cbc0010I After 4179 nodes, 180 on tree, -4249500 best solution, best possible -4251537.1 (178.09 seconds)
# Cbc0010I After 4201 nodes, 175 on tree, -4249500 best solution, best possible -4251537.1 (178.88 seconds)
# Cbc0010I After 4219 nodes, 179 on tree, -4249500 best solution, best possible -4251537.1 (179.59 seconds)
# Cbc0010I After 4243 nodes, 173 on tree, -4249500 best solution, best possible -4251537.1 (180.30 seconds)
# Cbc0010I After 4263 nodes, 174 on tree, -4249500 best solution, best possible -4251537.1 (181.03 seconds)
# Cbc0010I After 4279 nodes, 170 on tree, -4249500 best solution, best possible -4251537.1 (181.73 seconds)
# Cbc0010I After 4299 nodes, 172 on tree, -4249500 best solution, best possible -4251537.1 (182.44 seconds)
# Cbc0010I After 4323 nodes, 174 on tree, -4249500 best solution, best possible -4251537.1 (183.16 seconds)
# Cbc0010I After 4345 nodes, 172 on tree, -4249500 best solution, best possible -4251537.1 (183.86 seconds)
# Cbc0010I After 4373 nodes, 172 on tree, -4249500 best solution, best possible -4251537.1 (184.62 seconds)
# Cbc0010I After 4401 nodes, 172 on tree, -4249500 best solution, best possible -4251537.1 (185.33 seconds)
# Cbc0010I After 4429 nodes, 170 on tree, -4249500 best solution, best possible -4251537.1 (186.06 seconds)
# Cbc0010I After 4448 nodes, 169 on tree, -4249500 best solution, best possible -4251537.1 (186.77 seconds)
# Cbc0010I After 4473 nodes, 170 on tree, -4249500 best solution, best possible -4251537.1 (187.49 seconds)
# Cbc0010I After 4495 nodes, 170 on tree, -4249500 best solution, best possible -4251537.1 (188.23 seconds)
# Cbc0010I After 4519 nodes, 170 on tree, -4249500 best solution, best possible -4251537.1 (188.95 seconds)
# Cbc0010I After 4546 nodes, 168 on tree, -4249500 best solution, best possible -4251537.1 (189.66 seconds)
# Cbc0010I After 4571 nodes, 168 on tree, -4249500 best solution, best possible -4251537.1 (190.38 seconds)
# Cbc0010I After 4593 nodes, 165 on tree, -4249500 best solution, best possible -4251537.1 (191.11 seconds)
# Cbc0010I After 4627 nodes, 165 on tree, -4249500 best solution, best possible -4251537.1 (191.82 seconds)
# Cbc0010I After 4650 nodes, 164 on tree, -4249500 best solution, best possible -4251537.1 (192.55 seconds)
# Cbc0010I After 4672 nodes, 163 on tree, -4249500 best solution, best possible -4251537.1 (193.26 seconds)
# Cbc0010I After 4701 nodes, 161 on tree, -4249500 best solution, best possible -4251537.1 (193.99 seconds)
# Cbc0010I After 4732 nodes, 161 on tree, -4249500 best solution, best possible -4251537.1 (194.69 seconds)
# Cbc0010I After 4757 nodes, 160 on tree, -4249500 best solution, best possible -4251537.1 (195.41 seconds)
# Cbc0010I After 4778 nodes, 159 on tree, -4249500 best solution, best possible -4251537.1 (196.12 seconds)
# Cbc0010I After 4796 nodes, 157 on tree, -4249500 best solution, best possible -4251537.1 (196.82 seconds)
# Cbc0038I Full problem 2919 rows 4050 columns, reduced to 831 rows 672 columns
# Cbc0010I After 4812 nodes, 154 on tree, -4249500 best solution, best possible -4251537.1 (197.53 seconds)
# Cbc0010I After 4833 nodes, 152 on tree, -4249500 best solution, best possible -4251537.1 (198.33 seconds)
# Cbc0010I After 4853 nodes, 152 on tree, -4249500 best solution, best possible -4251537.1 (199.05 seconds)
# Cbc0010I After 4876 nodes, 152 on tree, -4249500 best solution, best possible -4251537.1 (199.75 seconds)
# Cbc0010I After 4894 nodes, 159 on tree, -4249500 best solution, best possible -4251537.1 (200.51 seconds)
# Cbc0010I After 4920 nodes, 148 on tree, -4249500 best solution, best possible -4251537.1 (201.24 seconds)
# Cbc0010I After 4937 nodes, 148 on tree, -4249500 best solution, best possible -4251537.1 (201.95 seconds)
# Cbc0010I After 4957 nodes, 155 on tree, -4249500 best solution, best possible -4251537.1 (202.65 seconds)
# Cbc0010I After 4982 nodes, 149 on tree, -4249500 best solution, best possible -4251537.1 (203.39 seconds)
# Cbc0010I After 5001 nodes, 147 on tree, -4249500 best solution, best possible -4251537.1 (204.11 seconds)
# Cbc0010I After 5011 nodes, 149 on tree, -4249500 best solution, best possible -4251537.1 (204.83 seconds)
# Cbc0010I After 5028 nodes, 157 on tree, -4249500 best solution, best possible -4251537.1 (205.68 seconds)
# Cbc0010I After 5047 nodes, 160 on tree, -4249500 best solution, best possible -4251537.1 (206.40 seconds)
# Cbc0010I After 5067 nodes, 159 on tree, -4249500 best solution, best possible -4251537.1 (207.15 seconds)
# Cbc0010I After 5087 nodes, 157 on tree, -4249500 best solution, best possible -4251537.1 (207.88 seconds)
# Cbc0010I After 5109 nodes, 158 on tree, -4249500 best solution, best possible -4251537.1 (208.58 seconds)
# Cbc0010I After 5123 nodes, 155 on tree, -4249500 best solution, best possible -4251537.1 (209.29 seconds)
# Cbc0010I After 5139 nodes, 155 on tree, -4249500 best solution, best possible -4251537.1 (210.07 seconds)
# Cbc0010I After 5159 nodes, 157 on tree, -4249500 best solution, best possible -4251537.1 (210.78 seconds)
# Cbc0010I After 5182 nodes, 154 on tree, -4249500 best solution, best possible -4251537.1 (211.48 seconds)
# Cbc0010I After 5205 nodes, 153 on tree, -4249500 best solution, best possible -4251537.1 (212.23 seconds)
# Cbc0010I After 5220 nodes, 153 on tree, -4249500 best solution, best possible -4251537.1 (212.95 seconds)
# Cbc0010I After 5242 nodes, 151 on tree, -4249500 best solution, best possible -4251537.1 (213.76 seconds)
# Cbc0010I After 5266 nodes, 150 on tree, -4249500 best solution, best possible -4251537.1 (214.46 seconds)
# Cbc0010I After 5288 nodes, 154 on tree, -4249500 best solution, best possible -4251537.1 (215.17 seconds)
# Cbc0010I After 5317 nodes, 149 on tree, -4249500 best solution, best possible -4251537.1 (215.95 seconds)
# Cbc0010I After 5337 nodes, 157 on tree, -4249500 best solution, best possible -4251537.1 (216.68 seconds)
# Cbc0010I After 5358 nodes, 154 on tree, -4249500 best solution, best possible -4251537.1 (217.45 seconds)
# Cbc0010I After 5379 nodes, 149 on tree, -4249500 best solution, best possible -4251537.1 (218.20 seconds)
# Cbc0038I Full problem 2919 rows 4050 columns, reduced to 1064 rows 857 columns
# Cbc0010I After 5400 nodes, 147 on tree, -4249500 best solution, best possible -4251537.1 (218.96 seconds)
# Cbc0010I After 5431 nodes, 145 on tree, -4249500 best solution, best possible -4251537.1 (219.68 seconds)
# Cbc0010I After 5452 nodes, 147 on tree, -4249500 best solution, best possible -4251537.1 (220.38 seconds)
# Cbc0010I After 5475 nodes, 145 on tree, -4249500 best solution, best possible -4251537.1 (221.11 seconds)
# Cbc0010I After 5505 nodes, 140 on tree, -4249500 best solution, best possible -4251537.1 (221.84 seconds)
# Cbc0010I After 5526 nodes, 145 on tree, -4249500 best solution, best possible -4251537.1 (222.59 seconds)
# Cbc0010I After 5549 nodes, 149 on tree, -4249500 best solution, best possible -4251537.1 (223.29 seconds)
# Cbc0010I After 5579 nodes, 140 on tree, -4249500 best solution, best possible -4251537.1 (224.06 seconds)
# Cbc0010I After 5600 nodes, 140 on tree, -4249500 best solution, best possible -4251537.1 (224.82 seconds)
# Cbc0010I After 5622 nodes, 142 on tree, -4249500 best solution, best possible -4251537.1 (225.57 seconds)
# Cbc0010I After 5650 nodes, 140 on tree, -4249500 best solution, best possible -4251537.1 (226.27 seconds)
# Cbc0010I After 5676 nodes, 142 on tree, -4249500 best solution, best possible -4251537.1 (227.02 seconds)
# Cbc0010I After 5698 nodes, 138 on tree, -4249500 best solution, best possible -4251537.1 (227.75 seconds)
# Cbc0010I After 5715 nodes, 146 on tree, -4249500 best solution, best possible -4251537.1 (228.45 seconds)
# Cbc0010I After 5728 nodes, 141 on tree, -4249500 best solution, best possible -4251537.1 (229.17 seconds)
# Cbc0010I After 5750 nodes, 137 on tree, -4249500 best solution, best possible -4251537.1 (229.88 seconds)
# Cbc0010I After 5775 nodes, 135 on tree, -4249500 best solution, best possible -4251537.1 (230.70 seconds)
# Cbc0010I After 5804 nodes, 135 on tree, -4249500 best solution, best possible -4251537.1 (231.41 seconds)
# Cbc0010I After 5825 nodes, 138 on tree, -4249500 best solution, best possible -4251537.1 (232.17 seconds)
# Cbc0010I After 5851 nodes, 131 on tree, -4249500 best solution, best possible -4251537.1 (232.90 seconds)
# Cbc0010I After 5874 nodes, 136 on tree, -4249500 best solution, best possible -4251537.1 (233.68 seconds)
# Cbc0010I After 5901 nodes, 131 on tree, -4249500 best solution, best possible -4251537.1 (234.39 seconds)
# Cbc0010I After 5930 nodes, 128 on tree, -4249500 best solution, best possible -4251537.1 (235.17 seconds)
# Cbc0010I After 5952 nodes, 132 on tree, -4249500 best solution, best possible -4251537.1 (236.06 seconds)
# Cbc0010I After 5976 nodes, 125 on tree, -4249500 best solution, best possible -4251537.1 (236.77 seconds)
# Cbc0010I After 5997 nodes, 129 on tree, -4249500 best solution, best possible -4251537.1 (237.52 seconds)
# Cbc0010I After 6017 nodes, 123 on tree, -4249500 best solution, best possible -4251537.1 (238.24 seconds)
# Cbc0010I After 6039 nodes, 119 on tree, -4249500 best solution, best possible -4251537.1 (238.98 seconds)
# Cbc0010I After 6066 nodes, 119 on tree, -4249500 best solution, best possible -4251537.1 (239.68 seconds)
# Cbc0010I After 6090 nodes, 117 on tree, -4249500 best solution, best possible -4251537.1 (240.41 seconds)
# Cbc0010I After 6112 nodes, 123 on tree, -4249500 best solution, best possible -4251537.1 (241.13 seconds)
# Cbc0010I After 6139 nodes, 115 on tree, -4249500 best solution, best possible -4251537.1 (241.87 seconds)
# Cbc0010I After 6159 nodes, 116 on tree, -4249500 best solution, best possible -4251537.1 (242.57 seconds)
# Cbc0010I After 6187 nodes, 113 on tree, -4249500 best solution, best possible -4251537.1 (243.31 seconds)
# Cbc0010I After 6212 nodes, 113 on tree, -4249500 best solution, best possible -4251537.1 (244.04 seconds)
# Cbc0010I After 6233 nodes, 112 on tree, -4249500 best solution, best possible -4251537.1 (244.78 seconds)
# Cbc0010I After 6267 nodes, 109 on tree, -4249500 best solution, best possible -4251537.1 (245.49 seconds)
# Cbc0010I After 6290 nodes, 116 on tree, -4249500 best solution, best possible -4251537.1 (246.20 seconds)
# Cbc0010I After 6313 nodes, 110 on tree, -4249500 best solution, best possible -4251537.1 (246.92 seconds)
# Cbc0010I After 6342 nodes, 113 on tree, -4249500 best solution, best possible -4251537.1 (247.66 seconds)
# Cbc0010I After 6366 nodes, 109 on tree, -4249500 best solution, best possible -4251537.1 (248.50 seconds)
# Cbc0010I After 6384 nodes, 114 on tree, -4249500 best solution, best possible -4251537.1 (249.26 seconds)
# Cbc0010I After 6405 nodes, 110 on tree, -4249500 best solution, best possible -4251537.1 (249.98 seconds)
# Cbc0010I After 6425 nodes, 108 on tree, -4249500 best solution, best possible -4251537.1 (250.68 seconds)
# Cbc0010I After 6447 nodes, 108 on tree, -4249500 best solution, best possible -4251537.1 (251.38 seconds)
# Cbc0010I After 6469 nodes, 108 on tree, -4249500 best solution, best possible -4251537.1 (252.10 seconds)
# Cbc0010I After 6502 nodes, 114 on tree, -4249500 best solution, best possible -4251537.1 (252.80 seconds)
# Cbc0010I After 6531 nodes, 111 on tree, -4249500 best solution, best possible -4251537.1 (253.57 seconds)
# Cbc0010I After 6564 nodes, 106 on tree, -4249500 best solution, best possible -4251537.1 (254.32 seconds)
# Cbc0010I After 6594 nodes, 105 on tree, -4249500 best solution, best possible -4251537.1 (255.02 seconds)
# Cbc0038I Full problem 2919 rows 4050 columns, reduced to 555 rows 464 columns
# Cbc0010I After 6615 nodes, 106 on tree, -4249500 best solution, best possible -4251537.1 (255.76 seconds)
# Cbc0010I After 6637 nodes, 109 on tree, -4249500 best solution, best possible -4251537.1 (256.47 seconds)
# Cbc0010I After 6656 nodes, 108 on tree, -4249500 best solution, best possible -4251537.1 (257.20 seconds)
# Cbc0010I After 6673 nodes, 106 on tree, -4249500 best solution, best possible -4251537.1 (257.91 seconds)
# Cbc0010I After 6690 nodes, 109 on tree, -4249500 best solution, best possible -4251537.1 (258.62 seconds)
# Cbc0010I After 6710 nodes, 105 on tree, -4249500 best solution, best possible -4251537.1 (259.32 seconds)
# Cbc0010I After 6733 nodes, 103 on tree, -4249500 best solution, best possible -4251537.1 (260.09 seconds)
# Cbc0010I After 6764 nodes, 101 on tree, -4249500 best solution, best possible -4251537.1 (260.80 seconds)
# Cbc0010I After 6781 nodes, 108 on tree, -4249500 best solution, best possible -4251537.1 (261.51 seconds)
# Cbc0010I After 6811 nodes, 106 on tree, -4249500 best solution, best possible -4251537.1 (262.23 seconds)
# Cbc0010I After 6834 nodes, 105 on tree, -4249500 best solution, best possible -4251537.1 (262.94 seconds)
# Cbc0010I After 6859 nodes, 102 on tree, -4249500 best solution, best possible -4251537.1 (263.68 seconds)
# Cbc0010I After 6882 nodes, 101 on tree, -4249500 best solution, best possible -4251537.1 (264.44 seconds)
# Cbc0010I After 6902 nodes, 105 on tree, -4249500 best solution, best possible -4251537.1 (265.15 seconds)
# Cbc0010I After 6925 nodes, 105 on tree, -4249500 best solution, best possible -4251537.1 (265.87 seconds)
# Cbc0010I After 6951 nodes, 99 on tree, -4249500 best solution, best possible -4251537.1 (26sol.cost 4249500.0 found, best possible: 4251537.124741856
